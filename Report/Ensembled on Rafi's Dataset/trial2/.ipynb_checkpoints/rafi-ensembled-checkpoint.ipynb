# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten, Concatenate
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
import numpy as np
import pandas as pd
import shutil
import time
from tensorflow.python.keras import layers

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report

# %%
data_dir=r'/kaggle/input/2nd-replication/Total/'
for i,d in enumerate([data_dir]):
    filepaths=[]
    labels=[]
    classlist=os.listdir(d)
    for klass in classlist:
        classpath=os.path.join(d,klass)
        if os.path.isdir(classpath):
            flist=os.listdir(classpath)
            for f in flist:
                fpath=os.path.join(classpath,f)
                filepaths.append(fpath)
                labels.append(klass)                   
    Fseries= pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')
    data_df=pd.concat([Fseries, Lseries], axis=1)
df=pd.concat([data_df], axis =0).reset_index(drop=True)# make a combined dataframe

print(df['labels'].value_counts())
# Out:
# t_resized_20    340
# t_resized_22    340
# t_resized_34    340
# t_resized_36    340
# t_resized_14    340
# t_resized_12    340
# t_resized_16    340
# t_resized_26    340
# t_resized_25    340
# t_resized_1     340
# t_resized_10    340
# t_resized_27    340
# t_resized_17    340
# t_resized_28    340
# t_resized_18    340
# t_resized_29    340
# t_resized_7     340
# t_resized_8     340
# t_resized_13    340
# t_resized_11    340
# t_resized_21    340
# t_resized_30    340
# t_resized_15    340
# t_resized_23    340
# t_resized_33    340
# t_resized_3     340
# t_resized_0     340
# t_resized_9     340
# t_resized_6     340
# t_resized_31    340
# t_resized_24    340
# t_resized_35    340
# t_resized_5     340
# t_resized_32    340
# t_resized_37    340
# t_resized_19    340
# t_resized_2     340
# t_resized_4     340
# Name: labels, dtype: int64

# %%
sample_size=340
sample_list=[]
group=df.groupby('labels')
for label in df['labels'].unique():    
    label_group=group.get_group(label).sample(sample_size, replace=False, random_state=123, axis=0)    
    sample_list.append(label_group)
df=pd.concat(sample_list, axis=0).reset_index(drop=False)
print (len(df))
# Out:
# 12920

# %%
train_split=.8
test_split=.1
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), ' test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  10336  test_df length:  1292   valid_df length:  1292

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
height=224
width=224
channels=3
batch_size=16
img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)
def scalar(img):
    return img/127.5-1  # scale pixel between -1 and +1
gen=ImageDataGenerator(preprocessing_function=scalar)
train_gen=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
test_gen=gen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)
valid_gen=gen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
classes=list(train_gen.class_indices.keys())
valid_classes=list(valid_gen.class_indices.keys())
class_count=len(classes)
# Out:
# test batch size:  76   test steps:  17
# Found 10336 validated image filenames belonging to 38 classes.
# Found 1292 validated image filenames belonging to 38 classes.
# Found 1292 validated image filenames belonging to 38 classes.

# %%
def show_image_samples(gen ):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<10:   #show maximum of 25 images
        r=length
    else:
        r=10
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=(images[i]+1 )/2 # scale images between 0 and 1 becaue pre-processor set them between -1 and +1
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
from tensorflow.keras.utils import to_categorical
print(classes)
print(valid_classes)
# Out:
# ['t_resized_0', 't_resized_1', 't_resized_10', 't_resized_11', 't_resized_12', 't_resized_13', 't_resized_14', 't_resized_15', 't_resized_16', 't_resized_17', 't_resized_18', 't_resized_19', 't_resized_2', 't_resized_20', 't_resized_21', 't_resized_22', 't_resized_23', 't_resized_24', 't_resized_25', 't_resized_26', 't_resized_27', 't_resized_28', 't_resized_29', 't_resized_3', 't_resized_30', 't_resized_31', 't_resized_32', 't_resized_33', 't_resized_34', 't_resized_35', 't_resized_36', 't_resized_37', 't_resized_4', 't_resized_5', 't_resized_6', 't_resized_7', 't_resized_8', 't_resized_9']
# ['t_resized_0', 't_resized_1', 't_resized_10', 't_resized_11', 't_resized_12', 't_resized_13', 't_resized_14', 't_resized_15', 't_resized_16', 't_resized_17', 't_resized_18', 't_resized_19', 't_resized_2', 't_resized_20', 't_resized_21', 't_resized_22', 't_resized_23', 't_resized_24', 't_resized_25', 't_resized_26', 't_resized_27', 't_resized_28', 't_resized_29', 't_resized_3', 't_resized_30', 't_resized_31', 't_resized_32', 't_resized_33', 't_resized_34', 't_resized_35', 't_resized_36', 't_resized_37', 't_resized_4', 't_resized_5', 't_resized_6', 't_resized_7', 't_resized_8', 't_resized_9']

# %%
IMG_SIZE=224

# %%
from tensorflow.keras.metrics import Recall, Precision, AUC, RootMeanSquaredError
from sklearn.metrics import f1_score

# %%
from tensorflow.keras.applications import VGG19, ResNet50
from tensorflow.keras.layers import Concatenate, Dense, Input,ZeroPadding2D, GlobalAveragePooling2D, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Recall,Precision

# %%
num_classes=len(classes)
print(num_classes)
# Out:
# 38

# %%
from tensorflow.keras.metrics import Recall, Precision

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, BatchNormalization, Flatten, Activation, MaxPooling2D, concatenate

# %%
def model(input_shape=[224,224, 3]):
    #base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)
    
    base_model = MobileNet(weights='imagenet', include_top=False,input_shape= input_shape)
    for layer in base_model.layers:
        layer.trainable = True
    x = base_model.output
    
    
    
    y= Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(x)
    y=Conv2D(64,(3,3), padding='same', activation='relu' )(y)
    y=BatchNormalization()(y)
    y=Activation('relu')(y)
    #y=MaxPooling2D(pool_size=(2, 2))(y)
    y=Dropout(0.25)(y)


    y=Conv2D(128,(5,5), padding='same', activation='relu')(y)
    y=BatchNormalization()(y)
    y=Activation('relu')(y)
    #y=MaxPooling2D(pool_size=(2, 2))(y)
    y=Dropout(0.25)(y)


    y=Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(y)
    y=BatchNormalization()(y)
    y=Activation('relu')(y)
    #y=MaxPooling2D(pool_size=(2, 2))(y)
    y=Dropout(0.25)(y)


    y=Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(y)
    y=BatchNormalization()(y)
    y=Activation('relu')(y)
    y=Dropout(0.25)(y)

    #Faltten the model
    y=Flatten()(y)


    y=Dense(256)(y)
    y=BatchNormalization()(y)
    y=Activation('relu')(y)
    y=Dropout(0.25)(y)


    y=Dense(512)(y)
    y=BatchNormalization()(y)
    y=Activation('relu')(y)
    y=Dropout(0.25)(y)

    y=Dense(64)(y)
    y=BatchNormalization()(y)
    y=Activation('relu')(y)

    

    

 

    # and a logistic layer -- let's say we have 200 classes
    predictions = Dense(38, activation='softmax')(y)
    model = Model(inputs= base_model.input, outputs=predictions)
    return model

# %%
model = model()

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 32)          294944
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# activation_14 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 7, 7, 128)         204928
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 7, 7, 128)         512
# _________________________________________________________________
# activation_15 (Activation)   (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 7, 7, 512)         590336
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_16 (Activation)   (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_17 (Activation)   (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               6422784
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_18 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_19 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                32832
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 64)                256
# _________________________________________________________________
# activation_20 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 38)                2470
# =================================================================
# Total params: 13,295,238
# Trainable params: 13,269,254
# Non-trainable params: 25,984
# _________________________________________________________________

# %%
model.compile(Adam(learning_rate=.001), loss='categorical_crossentropy', metrics=['accuracy', Precision(), Recall(), AUC(), 'mae', 'mse', RootMeanSquaredError()])

# %%
from keras.utils.vis_utils import plot_model
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

plot_model(model, to_file='model.png', show_shapes=True)

# %%
model_name='Own'

# %%
from tensorflow.python.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor= 'loss', patience=5,mode = 'min' ,verbose=1)

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %%
class LRA(keras.callbacks.Callback):
    reset=False
    count=0
    stop_count=0
    tepochs=0
    def __init__(self,model, patience,stop_patience, threshold, factor, dwell, model_name, freeze, initial_epoch):
        super(LRA, self).__init__()
        self.model=model
        self.patience=patience # specifies how many epochs without improvement before learning rate is adjusted
        self.stop_patience=stop_patience
        self.threshold=threshold # specifies training accuracy threshold when lr will be adjusted based on validation loss
        self.factor=factor # factor by which to reduce the learning rate
        self.dwell=dwell
        self.lr=float(tf.keras.backend.get_value(model.optimizer.lr)) # get the initiallearning rate and save it in self.lr
        self.highest_tracc=0.0 # set highest training accuracy to 0
        self.lowest_vloss=np.inf # set lowest validation loss to infinity
        #self.count=0 # initialize counter that counts epochs with no improvement
        #self.stop_count=0 # initialize counter that counts how manytimes lr has been adjustd with no improvement  
        self.initial_epoch=initial_epoch 
        #self.epochs=epochs
        best_weights=self.model.get_weights() # set a class vaiable so weights can be loaded after training is completed        
        msg=' '
        if freeze==True:
            msgs=f' Starting training using  base model { model_name} with weights frozen to imagenet weights initializing LRA callback'
        else:
            msgs=f' Starting training using base model { model_name} training all layers '            
        print_in_color (msgs, (244, 252, 3), (55,65,80)) 
        
    def on_epoch_begin(self,epoch, logs=None):
        self.now= time.time()
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        later=time.time()
        duration=later-self.now        
        if epoch== self.initial_epoch or LRA.reset==True:  
            LRA.reset=False           
            msg='{0:^8s}{1:^10s}{2:^9s}{3:^9s}{4:^9s}{5:^9s}{6:^9s}{7:^11s}{8:^8s}'.format('Epoch', 'Loss', 'Accuracy','V_loss','V_acc', 'LR', 'Next LR', 'Monitor', 'Duration')
            print_in_color(msg, (244,252,3), (55,65,80)) 
            
        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
        current_lr=lr
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        acc=logs.get('accuracy')  # get training accuracy 
        v_acc=logs.get('val_accuracy')
        loss=logs.get('loss')
        #print ( '\n',v_loss, self.lowest_vloss, acc, self.highest_tracc)
        if acc < self.threshold: # if training accuracy is below threshold adjust lr based on training accuracy
            monitor='accuracy'
            if acc>self.highest_tracc: # training accuracy improved in the epoch                
                self.highest_tracc=acc # set new highest training accuracy
                LRA.best_weights=self.model.get_weights() # traing accuracy improved so save the weights
                self.count=0 # set count to 0 since training accuracy improved
                self.stop_count=0 # set stop counter to 0
                if v_loss<self.lowest_vloss:
                    self.lowest_vloss=v_loss
                color= (0,255,0)
                self.lr=lr
            else: 
                # training accuracy did not improve check if this has happened for patience number of epochs
                # if so adjust learning rate
                if self.count>=self.patience -1:
                    color=(245, 170, 66)
                    self.lr= lr* self.factor # adjust the learning by factor
                    tf.keras.backend.set_value(self.model.optimizer.lr, self.lr) # set the learning rate in the optimizer
                    self.count=0 # reset the count to 0
                    self.stop_count=self.stop_count + 1
                    if self.dwell:
                        self.model.set_weights(LRA.best_weights) # return to better point in N space                        
                    else:
                        if v_loss<self.lowest_vloss:
                            self.lowest_vloss=v_loss                                    
                else:
                    self.count=self.count +1 # increment patience counter                    
        else: # training accuracy is above threshold so adjust learning rate based on validation loss
            monitor='val_loss'
            if v_loss< self.lowest_vloss: # check if the validation loss improved 
                self.lowest_vloss=v_loss # replace lowest validation loss with new validation loss                
                LRA.best_weights=self.model.get_weights() # validation loss improved so save the weights
                self.count=0 # reset count since validation loss improved  
                self.stop_count=0  
                color=(0,255,0)
                self.lr=lr
            else: # validation loss did not improve
                if self.count>=self.patience-1:
                    color=(245, 170, 66)
                    self.lr=self.lr * self.factor # adjust the learning rate
                    self.stop_count=self.stop_count + 1 # increment stop counter because lr was adjusted 
                    self.count=0 # reset counter
                    tf.keras.backend.set_value(self.model.optimizer.lr, self.lr) # set the learning rate in the optimizer
                    if self.dwell:
                        self.model.set_weights(LRA.best_weights) # return to better point in N space
                else: 
                    self.count =self.count +1 # increment the patience counter                    
                if acc>self.highest_tracc:
                    self.highest_tracc= acc
                    msg=f'{str(epoch+1):^3s}/{str(LRA.tepochs):4s} {loss:^9.3f}{acc*100:^9.3f}{v_loss:^9.5f}{v_acc*100:^9.3f}{current_lr:^9.5f}{self.lr:^9.5f}{monitor:^11s}{duration:^8.2f}'
                    print_in_color (msg,(0, 67, 54), (55,65,80))
        if self.stop_count> self.stop_patience - 1: # check if learning rate has been adjusted stop_count times with no improvement
            msg=f' training has been halted at epoch {epoch + 1} after {self.stop_patience} adjustments of learning rate with no improvement'
            print_in_color(msg, (0,255,0), (55,65,80))
            self.model.stop_training = True # stop training

# %%
epochs =110
patience= 15 # number of epochs to wait to adjust lr if monitored value does not improve
stop_patience =3 # number of epochs to wait before stopping training if monitored value does not improve
threshold=.9 # if train accuracy is < threshhold adjust monitor accuracy, else monitor validation loss
factor=.5 # factor to reduce lr by
dwell=True # experimental, if True and monitored metric does not improve on current epoch set  modelweights back to weights of previous epoch
freeze=False # if true free weights of  the base model
callbacks=[LRA(model=model,patience=patience,stop_patience=stop_patience, threshold=threshold,
                   factor=factor,dwell=dwell,model_name= model_name,  freeze=freeze, initial_epoch=0 )]
LRA.tepochs=epochs  # used to determine value of last epoch for printing
history=model.fit(train_gen,  epochs=epochs, callbacks=callbacks, verbose=1,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
#  Starting training using base model Own training all layers
#
# Epoch 1/110
# 2023-02-09 12:28:41.211049: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-02-09 12:28:46.548640: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 646/646 [==============================] - 100s 134ms/step - loss: 4.6690 - accuracy: 0.2236 - precision_1: 0.6527 - recall_1: 0.0211 - auc_1: 0.8665 - mae: 0.0464 - mse: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 2.2755 - val_accuracy: 0.3367 - val_precision_1: 0.6132 - val_recall_1: 0.1509 - val_auc_1: 0.9207 - val_mae: 0.0390 - val_mse: 0.0199 - val_root_mean_squared_error: 0.1411
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR   Monitor  Duration
#
# Epoch 2/110
# 646/646 [==============================] - 73s 113ms/step - loss: 1.7407 - accuracy: 0.4992 - precision_1: 0.6896 - recall_1: 0.2481 - auc_1: 0.9627 - mae: 0.0350 - mse: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 1.1585 - val_accuracy: 0.7098 - val_precision_1: 0.8265 - val_recall_1: 0.5751 - val_auc_1: 0.9834 - val_mae: 0.0239 - val_mse: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 3/110
# 646/646 [==============================] - 73s 113ms/step - loss: 1.3542 - accuracy: 0.6340 - precision_1: 0.7546 - recall_1: 0.4812 - auc_1: 0.9762 - mae: 0.0273 - mse: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 1.3438 - val_accuracy: 0.6432 - val_precision_1: 0.7444 - val_recall_1: 0.5410 - val_auc_1: 0.9737 - val_mae: 0.0247 - val_mse: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 4/110
# 646/646 [==============================] - 73s 113ms/step - loss: 1.1413 - accuracy: 0.7125 - precision_1: 0.8049 - recall_1: 0.6157 - auc_1: 0.9817 - mae: 0.0220 - mse: 0.0105 - root_mean_squared_error: 0.1025 - val_loss: 1.1345 - val_accuracy: 0.7423 - val_precision_1: 0.8067 - val_recall_1: 0.6912 - val_auc_1: 0.9787 - val_mae: 0.0183 - val_mse: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 5/110
# 646/646 [==============================] - 74s 114ms/step - loss: 1.0185 - accuracy: 0.7721 - precision_1: 0.8336 - recall_1: 0.7009 - auc_1: 0.9864 - mae: 0.0183 - mse: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 1.0558 - val_accuracy: 0.7740 - val_precision_1: 0.8186 - val_recall_1: 0.7407 - val_auc_1: 0.9829 - val_mae: 0.0147 - val_mse: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 6/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.9204 - accuracy: 0.8080 - precision_1: 0.8567 - recall_1: 0.7575 - auc_1: 0.9882 - mae: 0.0154 - mse: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.8139 - val_accuracy: 0.8320 - val_precision_1: 0.8669 - val_recall_1: 0.8119 - val_auc_1: 0.9869 - val_mae: 0.0120 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 7/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.8761 - accuracy: 0.8372 - precision_1: 0.8777 - recall_1: 0.7947 - auc_1: 0.9879 - mae: 0.0136 - mse: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.9665 - val_accuracy: 0.8266 - val_precision_1: 0.8502 - val_recall_1: 0.8042 - val_auc_1: 0.9791 - val_mae: 0.0124 - val_mse: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 8/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.7642 - accuracy: 0.8674 - precision_1: 0.8963 - recall_1: 0.8351 - auc_1: 0.9908 - mae: 0.0115 - mse: 0.0054 - root_mean_squared_error: 0.0738 - val_loss: 0.7925 - val_accuracy: 0.8568 - val_precision_1: 0.8966 - val_recall_1: 0.8320 - val_auc_1: 0.9897 - val_mae: 0.0114 - val_mse: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 9/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.7363 - accuracy: 0.8754 - precision_1: 0.9024 - recall_1: 0.8493 - auc_1: 0.9918 - mae: 0.0106 - mse: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.8494 - val_accuracy: 0.8584 - val_precision_1: 0.8852 - val_recall_1: 0.8413 - val_auc_1: 0.9855 - val_mae: 0.0103 - val_mse: 0.0057 - val_root_mean_squared_error: 0.0753
# Epoch 10/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.6937 - accuracy: 0.8868 - precision_1: 0.9112 - recall_1: 0.8646 - auc_1: 0.9920 - mae: 0.0097 - mse: 0.0047 - root_mean_squared_error: 0.0683 - val_loss: 0.7149 - val_accuracy: 0.8816 - val_precision_1: 0.9061 - val_recall_1: 0.8669 - val_auc_1: 0.9903 - val_mae: 0.0098 - val_mse: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 11/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.6081 - accuracy: 0.9070 - precision_1: 0.9270 - recall_1: 0.8891 - auc_1: 0.9933 - mae: 0.0083 - mse: 0.0039 - root_mean_squared_error: 0.0622 - val_loss: 0.6906 - val_accuracy: 0.8963 - val_precision_1: 0.9120 - val_recall_1: 0.8909 - val_auc_1: 0.9855 - val_mae: 0.0070 - val_mse: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 12/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.6157 - accuracy: 0.9063 - precision_1: 0.9253 - recall_1: 0.8909 - auc_1: 0.9925 - mae: 0.0080 - mse: 0.0039 - root_mean_squared_error: 0.0622 - val_loss: 0.8971 - val_accuracy: 0.8498 - val_precision_1: 0.8703 - val_recall_1: 0.8359 - val_auc_1: 0.9764 - val_mae: 0.0098 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0801
# 12 /110    0.616   90.635   0.89709  84.985   0.00100  0.00100  val_loss   73.53
#
# Epoch 13/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.5362 - accuracy: 0.9218 - precision_1: 0.9366 - recall_1: 0.9068 - auc_1: 0.9940 - mae: 0.0070 - mse: 0.0033 - root_mean_squared_error: 0.0576 - val_loss: 0.8778 - val_accuracy: 0.8498 - val_precision_1: 0.8859 - val_recall_1: 0.8289 - val_auc_1: 0.9801 - val_mae: 0.0102 - val_mse: 0.0061 - val_root_mean_squared_error: 0.0783
# 13 /110    0.536   92.183   0.87783  84.985   0.00100  0.00100  val_loss   73.38
#
# Epoch 14/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.5373 - accuracy: 0.9215 - precision_1: 0.9383 - recall_1: 0.9071 - auc_1: 0.9939 - mae: 0.0068 - mse: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.6913 - val_accuracy: 0.8916 - val_precision_1: 0.9102 - val_recall_1: 0.8862 - val_auc_1: 0.9853 - val_mae: 0.0069 - val_mse: 0.0044 - val_root_mean_squared_error: 0.0667
# Epoch 15/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.4692 - accuracy: 0.9334 - precision_1: 0.9472 - recall_1: 0.9228 - auc_1: 0.9952 - mae: 0.0058 - mse: 0.0027 - root_mean_squared_error: 0.0524 - val_loss: 0.7489 - val_accuracy: 0.8800 - val_precision_1: 0.8927 - val_recall_1: 0.8754 - val_auc_1: 0.9772 - val_mae: 0.0078 - val_mse: 0.0052 - val_root_mean_squared_error: 0.0718
# 15 /110    0.469   93.344   0.74886  88.003   0.00100  0.00100  val_loss   73.51
#
# Epoch 16/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.4682 - accuracy: 0.9315 - precision_1: 0.9430 - recall_1: 0.9211 - auc_1: 0.9950 - mae: 0.0059 - mse: 0.0029 - root_mean_squared_error: 0.0535 - val_loss: 0.6144 - val_accuracy: 0.8986 - val_precision_1: 0.9151 - val_recall_1: 0.8932 - val_auc_1: 0.9884 - val_mae: 0.0066 - val_mse: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 17/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.4320 - accuracy: 0.9394 - precision_1: 0.9499 - recall_1: 0.9301 - auc_1: 0.9950 - mae: 0.0053 - mse: 0.0026 - root_mean_squared_error: 0.0505 - val_loss: 0.7495 - val_accuracy: 0.8553 - val_precision_1: 0.8789 - val_recall_1: 0.8429 - val_auc_1: 0.9831 - val_mae: 0.0093 - val_mse: 0.0060 - val_root_mean_squared_error: 0.0772
# 17 /110    0.432   93.944   0.74951  85.526   0.00100  0.00100  val_loss   73.25
#
# Epoch 18/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.3884 - accuracy: 0.9465 - precision_1: 0.9561 - recall_1: 0.9390 - auc_1: 0.9956 - mae: 0.0048 - mse: 0.0023 - root_mean_squared_error: 0.0475 - val_loss: 0.5894 - val_accuracy: 0.9195 - val_precision_1: 0.9265 - val_recall_1: 0.9172 - val_auc_1: 0.9852 - val_mae: 0.0049 - val_mse: 0.0036 - val_root_mean_squared_error: 0.0596
# Epoch 19/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.4077 - accuracy: 0.9421 - precision_1: 0.9518 - recall_1: 0.9335 - auc_1: 0.9954 - mae: 0.0050 - mse: 0.0024 - root_mean_squared_error: 0.0494 - val_loss: 0.6089 - val_accuracy: 0.9087 - val_precision_1: 0.9203 - val_recall_1: 0.9033 - val_auc_1: 0.9846 - val_mae: 0.0059 - val_mse: 0.0041 - val_root_mean_squared_error: 0.0642
# 19 /110    0.408   94.214   0.60885  90.867   0.00100  0.00100  val_loss   73.68
#
# Epoch 20/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.3884 - accuracy: 0.9472 - precision_1: 0.9568 - recall_1: 0.9404 - auc_1: 0.9955 - mae: 0.0046 - mse: 0.0022 - root_mean_squared_error: 0.0474 - val_loss: 0.5680 - val_accuracy: 0.9033 - val_precision_1: 0.9230 - val_recall_1: 0.9002 - val_auc_1: 0.9833 - val_mae: 0.0059 - val_mse: 0.0039 - val_root_mean_squared_error: 0.0623
# Epoch 21/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.3195 - accuracy: 0.9579 - precision_1: 0.9641 - recall_1: 0.9525 - auc_1: 0.9962 - mae: 0.0038 - mse: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.5406 - val_accuracy: 0.9156 - val_precision_1: 0.9241 - val_recall_1: 0.9141 - val_auc_1: 0.9847 - val_mae: 0.0052 - val_mse: 0.0036 - val_root_mean_squared_error: 0.0597
# Epoch 22/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.3192 - accuracy: 0.9585 - precision_1: 0.9652 - recall_1: 0.9536 - auc_1: 0.9959 - mae: 0.0037 - mse: 0.0018 - root_mean_squared_error: 0.0422 - val_loss: 0.6029 - val_accuracy: 0.9017 - val_precision_1: 0.9184 - val_recall_1: 0.8978 - val_auc_1: 0.9803 - val_mae: 0.0057 - val_mse: 0.0041 - val_root_mean_squared_error: 0.0643
# 22 /110    0.319   95.849   0.60287  90.170   0.00100  0.00100  val_loss   73.57
#
# Epoch 23/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.2829 - accuracy: 0.9632 - precision_1: 0.9692 - recall_1: 0.9574 - auc_1: 0.9965 - mae: 0.0034 - mse: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 0.6308 - val_accuracy: 0.9133 - val_precision_1: 0.9215 - val_recall_1: 0.9087 - val_auc_1: 0.9823 - val_mae: 0.0051 - val_mse: 0.0038 - val_root_mean_squared_error: 0.0618
# 23 /110    0.283   96.324   0.63081  91.331   0.00100  0.00100  val_loss   73.80
#
# Epoch 24/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.3185 - accuracy: 0.9570 - precision_1: 0.9631 - recall_1: 0.9511 - auc_1: 0.9962 - mae: 0.0038 - mse: 0.0018 - root_mean_squared_error: 0.0430 - val_loss: 0.5951 - val_accuracy: 0.9133 - val_precision_1: 0.9238 - val_recall_1: 0.9102 - val_auc_1: 0.9816 - val_mae: 0.0052 - val_mse: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 25/110
# 646/646 [==============================] - 75s 115ms/step - loss: 0.2936 - accuracy: 0.9595 - precision_1: 0.9660 - recall_1: 0.9548 - auc_1: 0.9968 - mae: 0.0035 - mse: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 0.7011 - val_accuracy: 0.8885 - val_precision_1: 0.9017 - val_recall_1: 0.8808 - val_auc_1: 0.9787 - val_mae: 0.0069 - val_mse: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 26/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.2777 - accuracy: 0.9643 - precision_1: 0.9697 - recall_1: 0.9591 - auc_1: 0.9968 - mae: 0.0032 - mse: 0.0015 - root_mean_squared_error: 0.0392 - val_loss: 0.6040 - val_accuracy: 0.9002 - val_precision_1: 0.9104 - val_recall_1: 0.8971 - val_auc_1: 0.9798 - val_mae: 0.0058 - val_mse: 0.0043 - val_root_mean_squared_error: 0.0659
# 26 /110    0.278   96.430   0.60401  90.015   0.00100  0.00100  val_loss   72.71
#
# Epoch 27/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.2452 - accuracy: 0.9683 - precision_1: 0.9719 - recall_1: 0.9651 - auc_1: 0.9974 - mae: 0.0029 - mse: 0.0014 - root_mean_squared_error: 0.0369 - val_loss: 0.5256 - val_accuracy: 0.9226 - val_precision_1: 0.9300 - val_recall_1: 0.9149 - val_auc_1: 0.9844 - val_mae: 0.0048 - val_mse: 0.0035 - val_root_mean_squared_error: 0.0589
# Epoch 28/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.2465 - accuracy: 0.9677 - precision_1: 0.9720 - recall_1: 0.9641 - auc_1: 0.9971 - mae: 0.0029 - mse: 0.0014 - root_mean_squared_error: 0.0376 - val_loss: 0.5444 - val_accuracy: 0.9071 - val_precision_1: 0.9186 - val_recall_1: 0.9002 - val_auc_1: 0.9829 - val_mae: 0.0057 - val_mse: 0.0041 - val_root_mean_squared_error: 0.0637
# 28 /110    0.246   96.769   0.54436  90.712   0.00100  0.00100  val_loss   73.29
#
# Epoch 29/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.2333 - accuracy: 0.9704 - precision_1: 0.9738 - recall_1: 0.9677 - auc_1: 0.9970 - mae: 0.0026 - mse: 0.0013 - root_mean_squared_error: 0.0357 - val_loss: 0.6086 - val_accuracy: 0.9063 - val_precision_1: 0.9180 - val_recall_1: 0.9009 - val_auc_1: 0.9817 - val_mae: 0.0056 - val_mse: 0.0042 - val_root_mean_squared_error: 0.0647
# 29 /110    0.233   97.039   0.60858  90.635   0.00100  0.00100  val_loss   73.54
#
# Epoch 30/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.2436 - accuracy: 0.9677 - precision_1: 0.9714 - recall_1: 0.9638 - auc_1: 0.9967 - mae: 0.0028 - mse: 0.0014 - root_mean_squared_error: 0.0373 - val_loss: 0.5716 - val_accuracy: 0.8986 - val_precision_1: 0.9105 - val_recall_1: 0.8978 - val_auc_1: 0.9799 - val_mae: 0.0056 - val_mse: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 31/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.2133 - accuracy: 0.9730 - precision_1: 0.9765 - recall_1: 0.9696 - auc_1: 0.9971 - mae: 0.0025 - mse: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 0.5318 - val_accuracy: 0.9172 - val_precision_1: 0.9213 - val_recall_1: 0.9149 - val_auc_1: 0.9814 - val_mae: 0.0047 - val_mse: 0.0037 - val_root_mean_squared_error: 0.0605
# 31 /110    0.213   97.301   0.53183  91.718   0.00100  0.00100  val_loss   73.38
#
# Epoch 32/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.2189 - accuracy: 0.9722 - precision_1: 0.9763 - recall_1: 0.9688 - auc_1: 0.9970 - mae: 0.0025 - mse: 0.0012 - root_mean_squared_error: 0.0347 - val_loss: 0.4949 - val_accuracy: 0.9149 - val_precision_1: 0.9268 - val_recall_1: 0.9118 - val_auc_1: 0.9843 - val_mae: 0.0051 - val_mse: 0.0036 - val_root_mean_squared_error: 0.0599
# Epoch 33/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.2150 - accuracy: 0.9722 - precision_1: 0.9762 - recall_1: 0.9690 - auc_1: 0.9973 - mae: 0.0024 - mse: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 0.5139 - val_accuracy: 0.9226 - val_precision_1: 0.9316 - val_recall_1: 0.9172 - val_auc_1: 0.9827 - val_mae: 0.0044 - val_mse: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 34/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.2189 - accuracy: 0.9738 - precision_1: 0.9776 - recall_1: 0.9705 - auc_1: 0.9970 - mae: 0.0025 - mse: 0.0012 - root_mean_squared_error: 0.0341 - val_loss: 0.4344 - val_accuracy: 0.9257 - val_precision_1: 0.9328 - val_recall_1: 0.9234 - val_auc_1: 0.9862 - val_mae: 0.0043 - val_mse: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 35/110
# 646/646 [==============================] - 74s 115ms/step - loss: 0.2030 - accuracy: 0.9729 - precision_1: 0.9764 - recall_1: 0.9688 - auc_1: 0.9972 - mae: 0.0024 - mse: 0.0012 - root_mean_squared_error: 0.0342 - val_loss: 0.6532 - val_accuracy: 0.9071 - val_precision_1: 0.9183 - val_recall_1: 0.9048 - val_auc_1: 0.9715 - val_mae: 0.0055 - val_mse: 0.0042 - val_root_mean_squared_error: 0.0652
# Epoch 36/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.1801 - accuracy: 0.9777 - precision_1: 0.9809 - recall_1: 0.9749 - auc_1: 0.9973 - mae: 0.0021 - mse: 9.8034e-04 - root_mean_squared_error: 0.0313 - val_loss: 0.5371 - val_accuracy: 0.9156 - val_precision_1: 0.9253 - val_recall_1: 0.9102 - val_auc_1: 0.9784 - val_mae: 0.0051 - val_mse: 0.0037 - val_root_mean_squared_error: 0.0612
# 36 /110    0.180   97.775   0.53711  91.563   0.00100  0.00100  val_loss   73.35
#
# Epoch 37/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.1865 - accuracy: 0.9779 - precision_1: 0.9800 - recall_1: 0.9755 - auc_1: 0.9971 - mae: 0.0020 - mse: 9.7603e-04 - root_mean_squared_error: 0.0312 - val_loss: 0.4486 - val_accuracy: 0.9195 - val_precision_1: 0.9254 - val_recall_1: 0.9118 - val_auc_1: 0.9850 - val_mae: 0.0051 - val_mse: 0.0036 - val_root_mean_squared_error: 0.0598
# 37 /110    0.187   97.794   0.44863  91.950   0.00100  0.00100  val_loss   73.29
#
# Epoch 38/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.1709 - accuracy: 0.9787 - precision_1: 0.9817 - recall_1: 0.9766 - auc_1: 0.9976 - mae: 0.0020 - mse: 9.2966e-04 - root_mean_squared_error: 0.0305 - val_loss: 0.5344 - val_accuracy: 0.9172 - val_precision_1: 0.9292 - val_recall_1: 0.9141 - val_auc_1: 0.9829 - val_mae: 0.0046 - val_mse: 0.0036 - val_root_mean_squared_error: 0.0597
# 38 /110    0.171   97.872   0.53439  91.718   0.00100  0.00100  val_loss   73.45
#
# Epoch 39/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.1251 - accuracy: 0.9862 - precision_1: 0.9881 - recall_1: 0.9848 - auc_1: 0.9989 - mae: 0.0015 - mse: 6.1187e-04 - root_mean_squared_error: 0.0247 - val_loss: 0.4043 - val_accuracy: 0.9334 - val_precision_1: 0.9406 - val_recall_1: 0.9319 - val_auc_1: 0.9874 - val_mae: 0.0039 - val_mse: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 40/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.1665 - accuracy: 0.9823 - precision_1: 0.9847 - recall_1: 0.9806 - auc_1: 0.9976 - mae: 0.0017 - mse: 7.9758e-04 - root_mean_squared_error: 0.0282 - val_loss: 0.6068 - val_accuracy: 0.9125 - val_precision_1: 0.9237 - val_recall_1: 0.9094 - val_auc_1: 0.9788 - val_mae: 0.0051 - val_mse: 0.0039 - val_root_mean_squared_error: 0.0625
# 40 /110    0.167   98.229   0.60683  91.254   0.00100  0.00100  val_loss   73.25
#
# Epoch 41/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.1660 - accuracy: 0.9806 - precision_1: 0.9831 - recall_1: 0.9778 - auc_1: 0.9978 - mae: 0.0018 - mse: 8.5369e-04 - root_mean_squared_error: 0.0292 - val_loss: 0.5149 - val_accuracy: 0.9203 - val_precision_1: 0.9317 - val_recall_1: 0.9180 - val_auc_1: 0.9807 - val_mae: 0.0048 - val_mse: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 42/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.1757 - accuracy: 0.9767 - precision_1: 0.9802 - recall_1: 0.9747 - auc_1: 0.9980 - mae: 0.0020 - mse: 9.7078e-04 - root_mean_squared_error: 0.0312 - val_loss: 0.4499 - val_accuracy: 0.9319 - val_precision_1: 0.9397 - val_recall_1: 0.9296 - val_auc_1: 0.9832 - val_mae: 0.0039 - val_mse: 0.0030 - val_root_mean_squared_error: 0.0551
# Epoch 43/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.1529 - accuracy: 0.9816 - precision_1: 0.9845 - recall_1: 0.9792 - auc_1: 0.9980 - mae: 0.0017 - mse: 8.0484e-04 - root_mean_squared_error: 0.0284 - val_loss: 0.4527 - val_accuracy: 0.9249 - val_precision_1: 0.9318 - val_recall_1: 0.9203 - val_auc_1: 0.9834 - val_mae: 0.0044 - val_mse: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 44/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.1686 - accuracy: 0.9796 - precision_1: 0.9828 - recall_1: 0.9767 - auc_1: 0.9974 - mae: 0.0019 - mse: 9.1339e-04 - root_mean_squared_error: 0.0302 - val_loss: 0.5534 - val_accuracy: 0.9257 - val_precision_1: 0.9313 - val_recall_1: 0.9234 - val_auc_1: 0.9800 - val_mae: 0.0041 - val_mse: 0.0034 - val_root_mean_squared_error: 0.0586
# Epoch 45/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.1461 - accuracy: 0.9849 - precision_1: 0.9857 - recall_1: 0.9833 - auc_1: 0.9975 - mae: 0.0015 - mse: 7.1991e-04 - root_mean_squared_error: 0.0268 - val_loss: 0.5184 - val_accuracy: 0.9195 - val_precision_1: 0.9251 - val_recall_1: 0.9172 - val_auc_1: 0.9794 - val_mae: 0.0048 - val_mse: 0.0036 - val_root_mean_squared_error: 0.0597
# 45 /110    0.146   98.491   0.51836  91.950   0.00100  0.00100  val_loss   72.30
#
# Epoch 46/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.1652 - accuracy: 0.9810 - precision_1: 0.9835 - recall_1: 0.9794 - auc_1: 0.9976 - mae: 0.0018 - mse: 8.5957e-04 - root_mean_squared_error: 0.0293 - val_loss: 0.5287 - val_accuracy: 0.9187 - val_precision_1: 0.9256 - val_recall_1: 0.9149 - val_auc_1: 0.9803 - val_mae: 0.0045 - val_mse: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 47/110
# 646/646 [==============================] - 72s 111ms/step - loss: 0.1487 - accuracy: 0.9827 - precision_1: 0.9854 - recall_1: 0.9815 - auc_1: 0.9984 - mae: 0.0015 - mse: 7.2043e-04 - root_mean_squared_error: 0.0268 - val_loss: 0.4654 - val_accuracy: 0.9218 - val_precision_1: 0.9307 - val_recall_1: 0.9141 - val_auc_1: 0.9829 - val_mae: 0.0046 - val_mse: 0.0035 - val_root_mean_squared_error: 0.0588
# Epoch 48/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.1634 - accuracy: 0.9797 - precision_1: 0.9820 - recall_1: 0.9779 - auc_1: 0.9973 - mae: 0.0018 - mse: 8.9537e-04 - root_mean_squared_error: 0.0299 - val_loss: 0.6348 - val_accuracy: 0.9149 - val_precision_1: 0.9198 - val_recall_1: 0.9141 - val_auc_1: 0.9751 - val_mae: 0.0047 - val_mse: 0.0040 - val_root_mean_squared_error: 0.0633
# Epoch 49/110
# 646/646 [==============================] - 73s 112ms/step - loss: 0.1237 - accuracy: 0.9865 - precision_1: 0.9883 - recall_1: 0.9851 - auc_1: 0.9986 - mae: 0.0013 - mse: 5.8135e-04 - root_mean_squared_error: 0.0241 - val_loss: 0.7197 - val_accuracy: 0.9017 - val_precision_1: 0.9092 - val_recall_1: 0.8994 - val_auc_1: 0.9719 - val_mae: 0.0054 - val_mse: 0.0045 - val_root_mean_squared_error: 0.0674
# 49 /110    0.124   98.646   0.71974  90.170   0.00100  0.00100  val_loss   72.59
#
# Epoch 50/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.1497 - accuracy: 0.9831 - precision_1: 0.9858 - recall_1: 0.9812 - auc_1: 0.9975 - mae: 0.0016 - mse: 7.4908e-04 - root_mean_squared_error: 0.0274 - val_loss: 0.4865 - val_accuracy: 0.9203 - val_precision_1: 0.9285 - val_recall_1: 0.9141 - val_auc_1: 0.9803 - val_mae: 0.0051 - val_mse: 0.0038 - val_root_mean_squared_error: 0.0615
# Epoch 51/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.1073 - accuracy: 0.9892 - precision_1: 0.9911 - recall_1: 0.9880 - auc_1: 0.9990 - mae: 0.0011 - mse: 4.7301e-04 - root_mean_squared_error: 0.0217 - val_loss: 0.6360 - val_accuracy: 0.9125 - val_precision_1: 0.9153 - val_recall_1: 0.9118 - val_auc_1: 0.9735 - val_mae: 0.0047 - val_mse: 0.0040 - val_root_mean_squared_error: 0.0632
# 51 /110    0.107   98.916   0.63600  91.254   0.00100  0.00100  val_loss   73.23
#
# Epoch 52/110
# 646/646 [==============================] - 73s 112ms/step - loss: 0.1789 - accuracy: 0.9766 - precision_1: 0.9795 - recall_1: 0.9742 - auc_1: 0.9970 - mae: 0.0019 - mse: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 0.5196 - val_accuracy: 0.9211 - val_precision_1: 0.9272 - val_recall_1: 0.9164 - val_auc_1: 0.9793 - val_mae: 0.0048 - val_mse: 0.0037 - val_root_mean_squared_error: 0.0610
# Epoch 53/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.1392 - accuracy: 0.9845 - precision_1: 0.9863 - recall_1: 0.9827 - auc_1: 0.9978 - mae: 0.0015 - mse: 7.0285e-04 - root_mean_squared_error: 0.0265 - val_loss: 0.5144 - val_accuracy: 0.9195 - val_precision_1: 0.9243 - val_recall_1: 0.9164 - val_auc_1: 0.9789 - val_mae: 0.0047 - val_mse: 0.0037 - val_root_mean_squared_error: 0.0608
# Epoch 54/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.1539 - accuracy: 0.9820 - precision_1: 0.9843 - recall_1: 0.9797 - auc_1: 0.9981 - mae: 0.0016 - mse: 7.8606e-04 - root_mean_squared_error: 0.0280 - val_loss: 0.4609 - val_accuracy: 0.9156 - val_precision_1: 0.9289 - val_recall_1: 0.9102 - val_auc_1: 0.9852 - val_mae: 0.0056 - val_mse: 0.0036 - val_root_mean_squared_error: 0.0601
# Epoch 55/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0743 - accuracy: 0.9930 - precision_1: 0.9940 - recall_1: 0.9925 - auc_1: 0.9993 - mae: 8.3552e-04 - mse: 3.2259e-04 - root_mean_squared_error: 0.0180 - val_loss: 0.4360 - val_accuracy: 0.9389 - val_precision_1: 0.9417 - val_recall_1: 0.9373 - val_auc_1: 0.9824 - val_mae: 0.0035 - val_mse: 0.0030 - val_root_mean_squared_error: 0.0545
# 55 /110    0.074   99.303   0.43599  93.885   0.00050  0.00050  val_loss   72.99
#
# Epoch 56/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.0781 - accuracy: 0.9923 - precision_1: 0.9932 - recall_1: 0.9909 - auc_1: 0.9990 - mae: 8.5748e-04 - mse: 3.6855e-04 - root_mean_squared_error: 0.0192 - val_loss: 0.2967 - val_accuracy: 0.9450 - val_precision_1: 0.9501 - val_recall_1: 0.9435 - val_auc_1: 0.9891 - val_mae: 0.0033 - val_mse: 0.0024 - val_root_mean_squared_error: 0.0487
# Epoch 57/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0532 - accuracy: 0.9952 - precision_1: 0.9958 - recall_1: 0.9951 - auc_1: 0.9996 - mae: 5.8163e-04 - mse: 2.0880e-04 - root_mean_squared_error: 0.0145 - val_loss: 0.4298 - val_accuracy: 0.9350 - val_precision_1: 0.9400 - val_recall_1: 0.9342 - val_auc_1: 0.9832 - val_mae: 0.0036 - val_mse: 0.0030 - val_root_mean_squared_error: 0.0550
# 57 /110    0.053   99.516   0.42983  93.498   0.00050  0.00050  val_loss   73.31
#
# Epoch 58/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.0720 - accuracy: 0.9936 - precision_1: 0.9940 - recall_1: 0.9929 - auc_1: 0.9991 - mae: 6.8670e-04 - mse: 2.9974e-04 - root_mean_squared_error: 0.0173 - val_loss: 0.5226 - val_accuracy: 0.9272 - val_precision_1: 0.9329 - val_recall_1: 0.9257 - val_auc_1: 0.9815 - val_mae: 0.0040 - val_mse: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 59/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0792 - accuracy: 0.9933 - precision_1: 0.9941 - recall_1: 0.9923 - auc_1: 0.9989 - mae: 7.4163e-04 - mse: 3.1823e-04 - root_mean_squared_error: 0.0178 - val_loss: 0.4627 - val_accuracy: 0.9272 - val_precision_1: 0.9314 - val_recall_1: 0.9249 - val_auc_1: 0.9818 - val_mae: 0.0043 - val_mse: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 60/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0527 - accuracy: 0.9950 - precision_1: 0.9952 - recall_1: 0.9945 - auc_1: 0.9995 - mae: 5.2915e-04 - mse: 2.1908e-04 - root_mean_squared_error: 0.0148 - val_loss: 0.5413 - val_accuracy: 0.9342 - val_precision_1: 0.9363 - val_recall_1: 0.9327 - val_auc_1: 0.9777 - val_mae: 0.0036 - val_mse: 0.0032 - val_root_mean_squared_error: 0.0564
# Epoch 61/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0836 - accuracy: 0.9909 - precision_1: 0.9920 - recall_1: 0.9897 - auc_1: 0.9987 - mae: 8.2361e-04 - mse: 4.0980e-04 - root_mean_squared_error: 0.0202 - val_loss: 0.4299 - val_accuracy: 0.9327 - val_precision_1: 0.9360 - val_recall_1: 0.9288 - val_auc_1: 0.9828 - val_mae: 0.0037 - val_mse: 0.0031 - val_root_mean_squared_error: 0.0554
# Epoch 62/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0554 - accuracy: 0.9948 - precision_1: 0.9954 - recall_1: 0.9943 - auc_1: 0.9994 - mae: 5.8624e-04 - mse: 2.4119e-04 - root_mean_squared_error: 0.0155 - val_loss: 0.5517 - val_accuracy: 0.9249 - val_precision_1: 0.9327 - val_recall_1: 0.9226 - val_auc_1: 0.9761 - val_mae: 0.0041 - val_mse: 0.0035 - val_root_mean_squared_error: 0.0590
# Epoch 63/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0678 - accuracy: 0.9935 - precision_1: 0.9938 - recall_1: 0.9932 - auc_1: 0.9990 - mae: 6.4199e-04 - mse: 2.8873e-04 - root_mean_squared_error: 0.0170 - val_loss: 0.5479 - val_accuracy: 0.9358 - val_precision_1: 0.9409 - val_recall_1: 0.9358 - val_auc_1: 0.9773 - val_mae: 0.0035 - val_mse: 0.0031 - val_root_mean_squared_error: 0.0556
# Epoch 64/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.0635 - accuracy: 0.9939 - precision_1: 0.9945 - recall_1: 0.9935 - auc_1: 0.9991 - mae: 6.3830e-04 - mse: 2.8548e-04 - root_mean_squared_error: 0.0169 - val_loss: 0.5148 - val_accuracy: 0.9334 - val_precision_1: 0.9362 - val_recall_1: 0.9311 - val_auc_1: 0.9795 - val_mae: 0.0039 - val_mse: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 65/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0586 - accuracy: 0.9938 - precision_1: 0.9946 - recall_1: 0.9937 - auc_1: 0.9992 - mae: 5.9439e-04 - mse: 2.6781e-04 - root_mean_squared_error: 0.0164 - val_loss: 0.6281 - val_accuracy: 0.9156 - val_precision_1: 0.9163 - val_recall_1: 0.9149 - val_auc_1: 0.9745 - val_mae: 0.0045 - val_mse: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 66/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0551 - accuracy: 0.9945 - precision_1: 0.9952 - recall_1: 0.9940 - auc_1: 0.9992 - mae: 5.7260e-04 - mse: 2.4805e-04 - root_mean_squared_error: 0.0157 - val_loss: 0.5277 - val_accuracy: 0.9265 - val_precision_1: 0.9315 - val_recall_1: 0.9265 - val_auc_1: 0.9787 - val_mae: 0.0042 - val_mse: 0.0034 - val_root_mean_squared_error: 0.0587
# Epoch 67/110
# 646/646 [==============================] - 74s 114ms/step - loss: 0.0448 - accuracy: 0.9963 - precision_1: 0.9968 - recall_1: 0.9962 - auc_1: 0.9996 - mae: 4.1042e-04 - mse: 1.6372e-04 - root_mean_squared_error: 0.0128 - val_loss: 0.4846 - val_accuracy: 0.9389 - val_precision_1: 0.9454 - val_recall_1: 0.9381 - val_auc_1: 0.9817 - val_mae: 0.0032 - val_mse: 0.0028 - val_root_mean_squared_error: 0.0529
# 67 /110    0.045   99.632   0.48461  93.885   0.00050  0.00050  val_loss   73.56
#
# Epoch 68/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0852 - accuracy: 0.9914 - precision_1: 0.9923 - recall_1: 0.9904 - auc_1: 0.9987 - mae: 7.9800e-04 - mse: 4.0839e-04 - root_mean_squared_error: 0.0202 - val_loss: 0.5828 - val_accuracy: 0.9149 - val_precision_1: 0.9168 - val_recall_1: 0.9125 - val_auc_1: 0.9776 - val_mae: 0.0046 - val_mse: 0.0039 - val_root_mean_squared_error: 0.0623
# Epoch 69/110
# 646/646 [==============================] - 73s 112ms/step - loss: 0.0562 - accuracy: 0.9944 - precision_1: 0.9949 - recall_1: 0.9940 - auc_1: 0.9995 - mae: 5.7879e-04 - mse: 2.5417e-04 - root_mean_squared_error: 0.0159 - val_loss: 0.5017 - val_accuracy: 0.9365 - val_precision_1: 0.9379 - val_recall_1: 0.9350 - val_auc_1: 0.9800 - val_mae: 0.0034 - val_mse: 0.0030 - val_root_mean_squared_error: 0.0548
# Epoch 70/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0461 - accuracy: 0.9958 - precision_1: 0.9963 - recall_1: 0.9956 - auc_1: 0.9995 - mae: 4.5093e-04 - mse: 1.8530e-04 - root_mean_squared_error: 0.0136 - val_loss: 0.5197 - val_accuracy: 0.9334 - val_precision_1: 0.9376 - val_recall_1: 0.9311 - val_auc_1: 0.9777 - val_mae: 0.0036 - val_mse: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 71/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0612 - accuracy: 0.9941 - precision_1: 0.9950 - recall_1: 0.9939 - auc_1: 0.9993 - mae: 5.5889e-04 - mse: 2.5355e-04 - root_mean_squared_error: 0.0159 - val_loss: 0.4916 - val_accuracy: 0.9334 - val_precision_1: 0.9369 - val_recall_1: 0.9311 - val_auc_1: 0.9801 - val_mae: 0.0037 - val_mse: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 72/110
# 646/646 [==============================] - 72s 111ms/step - loss: 0.0400 - accuracy: 0.9964 - precision_1: 0.9966 - recall_1: 0.9961 - auc_1: 0.9995 - mae: 4.8838e-04 - mse: 1.7531e-04 - root_mean_squared_error: 0.0132 - val_loss: 0.3976 - val_accuracy: 0.9396 - val_precision_1: 0.9447 - val_recall_1: 0.9396 - val_auc_1: 0.9840 - val_mae: 0.0033 - val_mse: 0.0027 - val_root_mean_squared_error: 0.0522
# 72 /110    0.040   99.642   0.39757  93.963   0.00025  0.00025  val_loss   72.02
#
# Epoch 73/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0350 - accuracy: 0.9963 - precision_1: 0.9970 - recall_1: 0.9960 - auc_1: 0.9997 - mae: 4.4919e-04 - mse: 1.6967e-04 - root_mean_squared_error: 0.0130 - val_loss: 0.3803 - val_accuracy: 0.9435 - val_precision_1: 0.9477 - val_recall_1: 0.9404 - val_auc_1: 0.9836 - val_mae: 0.0032 - val_mse: 0.0026 - val_root_mean_squared_error: 0.0513
# Epoch 74/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0288 - accuracy: 0.9977 - precision_1: 0.9981 - recall_1: 0.9970 - auc_1: 0.9998 - mae: 3.5397e-04 - mse: 1.1377e-04 - root_mean_squared_error: 0.0107 - val_loss: 0.3583 - val_accuracy: 0.9412 - val_precision_1: 0.9447 - val_recall_1: 0.9389 - val_auc_1: 0.9848 - val_mae: 0.0032 - val_mse: 0.0027 - val_root_mean_squared_error: 0.0524
# 74 /110    0.029   99.768   0.35834  94.118   0.00025  0.00025  val_loss   72.97
#
# Epoch 75/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0245 - accuracy: 0.9980 - precision_1: 0.9984 - recall_1: 0.9979 - auc_1: 0.9997 - mae: 3.0021e-04 - mse: 9.3413e-05 - root_mean_squared_error: 0.0097 - val_loss: 0.4000 - val_accuracy: 0.9389 - val_precision_1: 0.9418 - val_recall_1: 0.9389 - val_auc_1: 0.9817 - val_mae: 0.0032 - val_mse: 0.0028 - val_root_mean_squared_error: 0.0531
# 75 /110    0.025   99.797   0.39999  93.885   0.00025  0.00025  val_loss   72.82
#
# Epoch 76/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0323 - accuracy: 0.9972 - precision_1: 0.9977 - recall_1: 0.9971 - auc_1: 0.9997 - mae: 3.4598e-04 - mse: 1.2208e-04 - root_mean_squared_error: 0.0110 - val_loss: 0.4850 - val_accuracy: 0.9327 - val_precision_1: 0.9362 - val_recall_1: 0.9311 - val_auc_1: 0.9788 - val_mae: 0.0037 - val_mse: 0.0032 - val_root_mean_squared_error: 0.0561
# Epoch 77/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0313 - accuracy: 0.9976 - precision_1: 0.9979 - recall_1: 0.9972 - auc_1: 0.9997 - mae: 3.0949e-04 - mse: 1.1280e-04 - root_mean_squared_error: 0.0106 - val_loss: 0.4021 - val_accuracy: 0.9389 - val_precision_1: 0.9403 - val_recall_1: 0.9381 - val_auc_1: 0.9821 - val_mae: 0.0033 - val_mse: 0.0029 - val_root_mean_squared_error: 0.0539
# Epoch 78/110
# 646/646 [==============================] - 73s 112ms/step - loss: 0.0287 - accuracy: 0.9973 - precision_1: 0.9975 - recall_1: 0.9973 - auc_1: 0.9997 - mae: 3.2949e-04 - mse: 1.3087e-04 - root_mean_squared_error: 0.0114 - val_loss: 0.4466 - val_accuracy: 0.9342 - val_precision_1: 0.9357 - val_recall_1: 0.9342 - val_auc_1: 0.9816 - val_mae: 0.0035 - val_mse: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 79/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0328 - accuracy: 0.9964 - precision_1: 0.9968 - recall_1: 0.9963 - auc_1: 0.9994 - mae: 3.4741e-04 - mse: 1.5091e-04 - root_mean_squared_error: 0.0123 - val_loss: 0.4989 - val_accuracy: 0.9327 - val_precision_1: 0.9369 - val_recall_1: 0.9311 - val_auc_1: 0.9793 - val_mae: 0.0036 - val_mse: 0.0031 - val_root_mean_squared_error: 0.0554
# Epoch 80/110
# 646/646 [==============================] - 72s 111ms/step - loss: 0.0264 - accuracy: 0.9980 - precision_1: 0.9982 - recall_1: 0.9978 - auc_1: 0.9996 - mae: 2.5386e-04 - mse: 9.8226e-05 - root_mean_squared_error: 0.0099 - val_loss: 0.4676 - val_accuracy: 0.9334 - val_precision_1: 0.9362 - val_recall_1: 0.9319 - val_auc_1: 0.9808 - val_mae: 0.0035 - val_mse: 0.0031 - val_root_mean_squared_error: 0.0555
# Epoch 81/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0242 - accuracy: 0.9983 - precision_1: 0.9985 - recall_1: 0.9979 - auc_1: 0.9998 - mae: 2.4445e-04 - mse: 8.1557e-05 - root_mean_squared_error: 0.0090 - val_loss: 0.4360 - val_accuracy: 0.9373 - val_precision_1: 0.9394 - val_recall_1: 0.9365 - val_auc_1: 0.9805 - val_mae: 0.0034 - val_mse: 0.0030 - val_root_mean_squared_error: 0.0545
# 81 /110    0.024   99.826   0.43597  93.731   0.00025  0.00025  val_loss   72.22
#
# Epoch 82/110
# 646/646 [==============================] - 73s 112ms/step - loss: 0.0225 - accuracy: 0.9984 - precision_1: 0.9985 - recall_1: 0.9984 - auc_1: 0.9997 - mae: 2.1859e-04 - mse: 7.8725e-05 - root_mean_squared_error: 0.0089 - val_loss: 0.4936 - val_accuracy: 0.9342 - val_precision_1: 0.9371 - val_recall_1: 0.9342 - val_auc_1: 0.9792 - val_mae: 0.0035 - val_mse: 0.0031 - val_root_mean_squared_error: 0.0555
# 82 /110    0.022   99.836   0.49359  93.421   0.00025  0.00025  val_loss   72.63
#
# Epoch 83/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0276 - accuracy: 0.9980 - precision_1: 0.9985 - recall_1: 0.9979 - auc_1: 0.9998 - mae: 2.5715e-04 - mse: 9.3378e-05 - root_mean_squared_error: 0.0097 - val_loss: 0.4376 - val_accuracy: 0.9373 - val_precision_1: 0.9402 - val_recall_1: 0.9373 - val_auc_1: 0.9797 - val_mae: 0.0034 - val_mse: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 84/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0279 - accuracy: 0.9975 - precision_1: 0.9976 - recall_1: 0.9972 - auc_1: 0.9996 - mae: 2.6219e-04 - mse: 1.0971e-04 - root_mean_squared_error: 0.0105 - val_loss: 0.4613 - val_accuracy: 0.9342 - val_precision_1: 0.9371 - val_recall_1: 0.9342 - val_auc_1: 0.9800 - val_mae: 0.0037 - val_mse: 0.0031 - val_root_mean_squared_error: 0.0558
# Epoch 85/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0331 - accuracy: 0.9975 - precision_1: 0.9979 - recall_1: 0.9970 - auc_1: 0.9998 - mae: 3.0232e-04 - mse: 1.2882e-04 - root_mean_squared_error: 0.0113 - val_loss: 0.4208 - val_accuracy: 0.9435 - val_precision_1: 0.9478 - val_recall_1: 0.9420 - val_auc_1: 0.9832 - val_mae: 0.0031 - val_mse: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 86/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0154 - accuracy: 0.9990 - precision_1: 0.9990 - recall_1: 0.9988 - auc_1: 0.9999 - mae: 1.5538e-04 - mse: 4.7528e-05 - root_mean_squared_error: 0.0069 - val_loss: 0.3667 - val_accuracy: 0.9474 - val_precision_1: 0.9487 - val_recall_1: 0.9443 - val_auc_1: 0.9849 - val_mae: 0.0030 - val_mse: 0.0026 - val_root_mean_squared_error: 0.0508
# 86 /110    0.015   99.903   0.36673  94.737   0.00025  0.00013  val_loss   72.70
#
# Epoch 87/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0307 - accuracy: 0.9972 - precision_1: 0.9975 - recall_1: 0.9971 - auc_1: 0.9995 - mae: 4.2629e-04 - mse: 1.4151e-04 - root_mean_squared_error: 0.0119 - val_loss: 0.3882 - val_accuracy: 0.9412 - val_precision_1: 0.9455 - val_recall_1: 0.9404 - val_auc_1: 0.9852 - val_mae: 0.0032 - val_mse: 0.0028 - val_root_mean_squared_error: 0.0525
# Epoch 88/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0195 - accuracy: 0.9985 - precision_1: 0.9986 - recall_1: 0.9983 - auc_1: 0.9998 - mae: 3.1622e-04 - mse: 8.3737e-05 - root_mean_squared_error: 0.0092 - val_loss: 0.3496 - val_accuracy: 0.9450 - val_precision_1: 0.9471 - val_recall_1: 0.9427 - val_auc_1: 0.9860 - val_mae: 0.0030 - val_mse: 0.0025 - val_root_mean_squared_error: 0.0504
# Epoch 89/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0164 - accuracy: 0.9985 - precision_1: 0.9987 - recall_1: 0.9985 - auc_1: 0.9997 - mae: 2.5813e-04 - mse: 6.7428e-05 - root_mean_squared_error: 0.0082 - val_loss: 0.3538 - val_accuracy: 0.9489 - val_precision_1: 0.9504 - val_recall_1: 0.9489 - val_auc_1: 0.9845 - val_mae: 0.0028 - val_mse: 0.0024 - val_root_mean_squared_error: 0.0487
# Epoch 90/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0188 - accuracy: 0.9982 - precision_1: 0.9984 - recall_1: 0.9980 - auc_1: 0.9998 - mae: 2.8024e-04 - mse: 8.6976e-05 - root_mean_squared_error: 0.0093 - val_loss: 0.3585 - val_accuracy: 0.9474 - val_precision_1: 0.9495 - val_recall_1: 0.9458 - val_auc_1: 0.9852 - val_mae: 0.0030 - val_mse: 0.0025 - val_root_mean_squared_error: 0.0499
# Epoch 91/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0196 - accuracy: 0.9983 - precision_1: 0.9984 - recall_1: 0.9982 - auc_1: 0.9997 - mae: 2.5975e-04 - mse: 8.3644e-05 - root_mean_squared_error: 0.0091 - val_loss: 0.3711 - val_accuracy: 0.9466 - val_precision_1: 0.9501 - val_recall_1: 0.9435 - val_auc_1: 0.9841 - val_mae: 0.0029 - val_mse: 0.0025 - val_root_mean_squared_error: 0.0497
# Epoch 92/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0169 - accuracy: 0.9987 - precision_1: 0.9989 - recall_1: 0.9986 - auc_1: 0.9999 - mae: 2.1070e-04 - mse: 6.1462e-05 - root_mean_squared_error: 0.0078 - val_loss: 0.3460 - val_accuracy: 0.9505 - val_precision_1: 0.9526 - val_recall_1: 0.9489 - val_auc_1: 0.9848 - val_mae: 0.0029 - val_mse: 0.0024 - val_root_mean_squared_error: 0.0492
# Epoch 93/110
# 646/646 [==============================] - 72s 112ms/step - loss: 0.0161 - accuracy: 0.9989 - precision_1: 0.9990 - recall_1: 0.9986 - auc_1: 0.9999 - mae: 2.1756e-04 - mse: 5.8034e-05 - root_mean_squared_error: 0.0076 - val_loss: 0.3585 - val_accuracy: 0.9466 - val_precision_1: 0.9517 - val_recall_1: 0.9458 - val_auc_1: 0.9833 - val_mae: 0.0029 - val_mse: 0.0025 - val_root_mean_squared_error: 0.0500
# Epoch 94/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0196 - accuracy: 0.9985 - precision_1: 0.9985 - recall_1: 0.9985 - auc_1: 0.9997 - mae: 2.1958e-04 - mse: 7.9131e-05 - root_mean_squared_error: 0.0089 - val_loss: 0.3937 - val_accuracy: 0.9466 - val_precision_1: 0.9488 - val_recall_1: 0.9466 - val_auc_1: 0.9813 - val_mae: 0.0029 - val_mse: 0.0025 - val_root_mean_squared_error: 0.0502
# Epoch 95/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0115 - accuracy: 0.9993 - precision_1: 0.9993 - recall_1: 0.9992 - auc_1: 0.9999 - mae: 1.7344e-04 - mse: 4.3564e-05 - root_mean_squared_error: 0.0066 - val_loss: 0.4512 - val_accuracy: 0.9458 - val_precision_1: 0.9480 - val_recall_1: 0.9450 - val_auc_1: 0.9789 - val_mae: 0.0029 - val_mse: 0.0026 - val_root_mean_squared_error: 0.0508
# 95 /110    0.011   99.932   0.45116  94.582   0.00013  0.00013  val_loss   72.82
#
# Epoch 96/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0165 - accuracy: 0.9985 - precision_1: 0.9986 - recall_1: 0.9985 - auc_1: 0.9999 - mae: 1.9967e-04 - mse: 7.0788e-05 - root_mean_squared_error: 0.0084 - val_loss: 0.3842 - val_accuracy: 0.9466 - val_precision_1: 0.9479 - val_recall_1: 0.9443 - val_auc_1: 0.9833 - val_mae: 0.0029 - val_mse: 0.0025 - val_root_mean_squared_error: 0.0503
# Epoch 97/110
# 646/646 [==============================] - 73s 114ms/step - loss: 0.0164 - accuracy: 0.9985 - precision_1: 0.9988 - recall_1: 0.9985 - auc_1: 0.9998 - mae: 1.8567e-04 - mse: 7.0992e-05 - root_mean_squared_error: 0.0084 - val_loss: 0.4027 - val_accuracy: 0.9474 - val_precision_1: 0.9502 - val_recall_1: 0.9450 - val_auc_1: 0.9817 - val_mae: 0.0029 - val_mse: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 98/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0141 - accuracy: 0.9991 - precision_1: 0.9991 - recall_1: 0.9989 - auc_1: 0.9998 - mae: 1.6473e-04 - mse: 4.9153e-05 - root_mean_squared_error: 0.0070 - val_loss: 0.4025 - val_accuracy: 0.9489 - val_precision_1: 0.9510 - val_recall_1: 0.9466 - val_auc_1: 0.9817 - val_mae: 0.0028 - val_mse: 0.0025 - val_root_mean_squared_error: 0.0503
# Epoch 99/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0123 - accuracy: 0.9989 - precision_1: 0.9991 - recall_1: 0.9988 - auc_1: 0.9999 - mae: 1.5728e-04 - mse: 4.6865e-05 - root_mean_squared_error: 0.0068 - val_loss: 0.4018 - val_accuracy: 0.9466 - val_precision_1: 0.9488 - val_recall_1: 0.9466 - val_auc_1: 0.9829 - val_mae: 0.0029 - val_mse: 0.0026 - val_root_mean_squared_error: 0.0505
# Epoch 100/110
# 646/646 [==============================] - 73s 113ms/step - loss: 0.0146 - accuracy: 0.9986 - precision_1: 0.9987 - recall_1: 0.9985 - auc_1: 0.9999 - mae: 1.7359e-04 - mse: 6.3493e-05 - root_mean_squared_error: 0.0080 - val_loss: 0.4225 - val_accuracy: 0.9427 - val_precision_1: 0.9471 - val_recall_1: 0.9420 - val_auc_1: 0.9801 - val_mae: 0.0032 - val_mse: 0.0027 - val_root_mean_squared_error: 0.0523
# Epoch 101/110
# 646/646 [==============================] - 73s 112ms/step - loss: 0.0164 - accuracy: 0.9988 - precision_1: 0.9989 - recall_1: 0.9985 - auc_1: 0.9999 - mae: 1.8298e-04 - mse: 5.9450e-05 - root_mean_squared_error: 0.0077 - val_loss: 0.4163 - val_accuracy: 0.9443 - val_precision_1: 0.9464 - val_recall_1: 0.9435 - val_auc_1: 0.9809 - val_mae: 0.0030 - val_mse: 0.0027 - val_root_mean_squared_error: 0.0520
#  training has been halted at epoch 101 after 3 adjustments of learning rate with no improvement

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 38:
        # create a confusion matrix 
        cm = confusion_matrix(y_true, y_pred )        
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %%
tr_plot(history,0)
save_dir=r'./'
subject='fruits'
acc=model.evaluate( test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1]*100
msg=f'accuracy on the test set is {acc:5.2f} %'
print_in_color(msg, (0,255,0),(55,65,80))
save_id=str (model_name +  '-' + subject +'-'+ str(acc)[:str(acc).rfind('.')+3] + '.h5')
save_loc=os.path.join(save_dir, save_id)
model.save(save_loc)
# Out:
# 17/17 [==============================] - 4s 197ms/step - loss: 0.2663 - accuracy: 0.9551 - precision_1: 0.9596 - recall_1: 0.9551 - auc_1: 0.9899 - mae: 0.0028 - mse: 0.0021 - root_mean_squared_error: 0.0455
# accuracy on the test set is 95.51 %

# %%
print_code=0
preds=model.predict(test_gen) 
print_info( test_gen, preds, print_code, save_dir, subject )
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#  t_resized_0       0.93      0.93      0.93        45
#  t_resized_1       0.97      0.92      0.94        36
# t_resized_10       1.00      1.00      1.00        27
# t_resized_11       1.00      1.00      1.00        39
# t_resized_12       1.00      1.00      1.00        39
# t_resized_13       0.94      0.97      0.95        30
# t_resized_14       0.92      0.88      0.90        40
# t_resized_15       0.89      0.89      0.89        28
# t_resized_16       0.92      0.97      0.94        35
# t_resized_17       1.00      1.00      1.00        43
# t_resized_18       0.83      0.92      0.87        26
# t_resized_19       1.00      0.97      0.99        39
#  t_resized_2       1.00      0.94      0.97        33
# t_resized_20       1.00      1.00      1.00        40
# t_resized_21       1.00      0.96      0.98        28
# t_resized_22       0.79      0.97      0.87        35
# t_resized_23       0.94      0.92      0.93        36
# t_resized_24       1.00      0.94      0.97        31
# t_resized_25       0.87      1.00      0.93        33
# t_resized_26       1.00      0.86      0.93        36
# t_resized_27       1.00      0.91      0.96        35
# t_resized_28       0.97      0.95      0.96        38
# t_resized_29       0.94      0.97      0.96        33
#  t_resized_3       0.88      0.77      0.82        39
# t_resized_30       1.00      0.95      0.97        37
# t_resized_31       0.91      1.00      0.95        20
# t_resized_32       0.93      0.97      0.95        29
# t_resized_33       0.93      1.00      0.96        38
# t_resized_34       1.00      0.97      0.99        34
# t_resized_35       0.96      0.93      0.95        28
# t_resized_36       1.00      1.00      1.00        29
# t_resized_37       1.00      0.97      0.99        38
#  t_resized_4       0.91      1.00      0.95        31
#  t_resized_5       0.97      0.97      0.97        31
#  t_resized_6       1.00      1.00      1.00        35
#  t_resized_7       0.92      0.96      0.94        25
#  t_resized_8       1.00      1.00      1.00        36
#  t_resized_9       0.97      0.97      0.97        37
#
#     accuracy                           0.96      1292
#    macro avg       0.96      0.96      0.95      1292
# weighted avg       0.96      0.96      0.96      1292
