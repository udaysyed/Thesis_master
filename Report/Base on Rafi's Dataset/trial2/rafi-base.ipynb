# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
import numpy as np
import pandas as pd
import shutil
import time
from tensorflow.python.keras import layers

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report

# %%
data_dir=r'/kaggle/input/2nd-replication/Total/'
for i,d in enumerate([data_dir]):
    filepaths=[]
    labels=[]
    classlist=os.listdir(d)
    for klass in classlist:
        classpath=os.path.join(d,klass)
        if os.path.isdir(classpath):
            flist=os.listdir(classpath)
            for f in flist:
                fpath=os.path.join(classpath,f)
                filepaths.append(fpath)
                labels.append(klass)                   
    Fseries= pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')
    data_df=pd.concat([Fseries, Lseries], axis=1)
df=pd.concat([data_df], axis =0).reset_index(drop=True)# make a combined dataframe

print(df['labels'].value_counts())
# Out:
# t_resized_20    340
# t_resized_22    340
# t_resized_34    340
# t_resized_36    340
# t_resized_14    340
# t_resized_12    340
# t_resized_16    340
# t_resized_26    340
# t_resized_25    340
# t_resized_1     340
# t_resized_10    340
# t_resized_27    340
# t_resized_17    340
# t_resized_28    340
# t_resized_18    340
# t_resized_29    340
# t_resized_7     340
# t_resized_8     340
# t_resized_13    340
# t_resized_11    340
# t_resized_21    340
# t_resized_30    340
# t_resized_15    340
# t_resized_23    340
# t_resized_33    340
# t_resized_3     340
# t_resized_0     340
# t_resized_9     340
# t_resized_6     340
# t_resized_31    340
# t_resized_24    340
# t_resized_35    340
# t_resized_5     340
# t_resized_32    340
# t_resized_37    340
# t_resized_19    340
# t_resized_2     340
# t_resized_4     340
# Name: labels, dtype: int64

# %%
sample_size=340
sample_list=[]
group=df.groupby('labels')
for label in df['labels'].unique():    
    label_group=group.get_group(label).sample(sample_size, replace=False, random_state=123, axis=0)    
    sample_list.append(label_group)
df=pd.concat(sample_list, axis=0).reset_index(drop=False)
print (len(df))
# Out:
# 12920

# %%
train_split=.8
test_split=.1
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), ' test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  10336  test_df length:  1292   valid_df length:  1292

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
height=224
width=224
channels=3
batch_size=16
img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)
def scalar(img):
    return img/127.5-1  # scale pixel between -1 and +1
gen=ImageDataGenerator(preprocessing_function=scalar)
train_gen=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
test_gen=gen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)
valid_gen=gen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
classes=list(train_gen.class_indices.keys())
valid_classes=list(valid_gen.class_indices.keys())
class_count=len(classes)
# Out:
# test batch size:  76   test steps:  17
# Found 10336 validated image filenames belonging to 38 classes.
# Found 1292 validated image filenames belonging to 38 classes.
# Found 1292 validated image filenames belonging to 38 classes.

# %%
from tensorflow.keras.utils import to_categorical
print(classes)
print(valid_classes)
# Out:
# ['t_resized_0', 't_resized_1', 't_resized_10', 't_resized_11', 't_resized_12', 't_resized_13', 't_resized_14', 't_resized_15', 't_resized_16', 't_resized_17', 't_resized_18', 't_resized_19', 't_resized_2', 't_resized_20', 't_resized_21', 't_resized_22', 't_resized_23', 't_resized_24', 't_resized_25', 't_resized_26', 't_resized_27', 't_resized_28', 't_resized_29', 't_resized_3', 't_resized_30', 't_resized_31', 't_resized_32', 't_resized_33', 't_resized_34', 't_resized_35', 't_resized_36', 't_resized_37', 't_resized_4', 't_resized_5', 't_resized_6', 't_resized_7', 't_resized_8', 't_resized_9']
# ['t_resized_0', 't_resized_1', 't_resized_10', 't_resized_11', 't_resized_12', 't_resized_13', 't_resized_14', 't_resized_15', 't_resized_16', 't_resized_17', 't_resized_18', 't_resized_19', 't_resized_2', 't_resized_20', 't_resized_21', 't_resized_22', 't_resized_23', 't_resized_24', 't_resized_25', 't_resized_26', 't_resized_27', 't_resized_28', 't_resized_29', 't_resized_3', 't_resized_30', 't_resized_31', 't_resized_32', 't_resized_33', 't_resized_34', 't_resized_35', 't_resized_36', 't_resized_37', 't_resized_4', 't_resized_5', 't_resized_6', 't_resized_7', 't_resized_8', 't_resized_9']

# %%
IMG_SIZE=224

# %%
from tensorflow.keras.metrics import Recall, Precision, AUC, RootMeanSquaredError
from sklearn.metrics import f1_score

# %%
num_classes=len(classes)
print(num_classes)
# Out:
# 38

# %%
from tensorflow.keras.metrics import Recall, Precision

# %%
def model_2(input_size, classes=38):
    
    model= tf.keras.models.Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=input_size))
    model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))


    model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    

    model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))


    model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    #Faltten the model
    model.add(Flatten())
    
    
    model.add(Dense(256))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    
    
    model.add(Dense(512))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(64))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
   

    model.add(Dense(classes, activation='softmax'))
    opt = Adam(lr=0.0001 , decay=1e-6)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy', Precision(), Recall(), AUC(), 'mae', 'mse', RootMeanSquaredError()])
    return model

# %%
model=model_2(input_size=(224,224,3))
# Out:
# 2023-02-09 14:52:56.006196: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.007297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.138371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.139398: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.140280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.141158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.142978: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-09 14:52:56.408747: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.409719: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.410575: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.411436: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.412238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:56.413074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:59.312803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:59.313805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:59.314540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:59.315248: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:59.315991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:59.316729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-02-09 14:52:59.320217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-09 14:52:59.320960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 224, 224, 64)      256
# _________________________________________________________________
# activation (Activation)      (None, 224, 224, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     204928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 128)     512
# _________________________________________________________________
# activation_1 (Activation)    (None, 112, 112, 128)     0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 512)       590336
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 56, 56, 512)       2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 56, 56, 512)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 512)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 512)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               25690368
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                32832
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# activation_6 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 38)                2470
# =================================================================
# Total params: 29,039,910
# Trainable params: 29,035,814
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

plot_model(model, to_file='model.png', show_shapes=True)

# %%
def show_image_samples(gen ):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<10:   #show maximum of 25 images
        r=length
    else:
        r=10
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=(images[i]+1 )/2 # scale images between 0 and 1 becaue pre-processor set them between -1 and +1
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
from tensorflow.python.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor= 'val_loss', patience=5,mode = 'min' ,verbose=1)

# %%
model_name='Mark1'

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %%
class LRA(keras.callbacks.Callback):
    reset=False
    count=0
    stop_count=0
    tepochs=0
    def __init__(self,model, patience,stop_patience, threshold, factor, dwell, model_name, freeze, initial_epoch):
        super(LRA, self).__init__()
        self.model=model
        self.patience=patience # specifies how many epochs without improvement before learning rate is adjusted
        self.stop_patience=stop_patience
        self.threshold=threshold # specifies training accuracy threshold when lr will be adjusted based on validation loss
        self.factor=factor # factor by which to reduce the learning rate
        self.dwell=dwell
        self.lr=float(tf.keras.backend.get_value(model.optimizer.lr)) # get the initiallearning rate and save it in self.lr
        self.highest_tracc=0.0 # set highest training accuracy to 0
        self.lowest_vloss=np.inf # set lowest validation loss to infinity
        #self.count=0 # initialize counter that counts epochs with no improvement
        #self.stop_count=0 # initialize counter that counts how manytimes lr has been adjustd with no improvement  
        self.initial_epoch=initial_epoch 
        #self.epochs=epochs
        best_weights=self.model.get_weights() # set a class vaiable so weights can be loaded after training is completed        
        msg=' '
        if freeze==True:
            msgs=f' Starting training using  base model { model_name} with weights frozen to imagenet weights initializing LRA callback'
        else:
            msgs=f' Starting training using base model { model_name} training all layers '            
        print_in_color (msgs, (244, 252, 3), (55,65,80)) 
        
    def on_epoch_begin(self,epoch, logs=None):
        self.now= time.time()
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        later=time.time()
        duration=later-self.now        
        if epoch== self.initial_epoch or LRA.reset==True:  
            LRA.reset=False           
            msg='{0:^8s}{1:^10s}{2:^9s}{3:^9s}{4:^9s}{5:^9s}{6:^9s}{7:^11s}{8:^8s}'.format('Epoch', 'Loss', 'Accuracy','V_loss','V_acc', 'LR', 'Next LR', 'Monitor', 'Duration')
            print_in_color(msg, (244,252,3), (55,65,80)) 
            
        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
        current_lr=lr
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        acc=logs.get('accuracy')  # get training accuracy 
        v_acc=logs.get('val_accuracy')
        loss=logs.get('loss')
        #print ( '\n',v_loss, self.lowest_vloss, acc, self.highest_tracc)
        if acc < self.threshold: # if training accuracy is below threshold adjust lr based on training accuracy
            monitor='accuracy'
            if acc>self.highest_tracc: # training accuracy improved in the epoch                
                self.highest_tracc=acc # set new highest training accuracy
                LRA.best_weights=self.model.get_weights() # traing accuracy improved so save the weights
                self.count=0 # set count to 0 since training accuracy improved
                self.stop_count=0 # set stop counter to 0
                if v_loss<self.lowest_vloss:
                    self.lowest_vloss=v_loss
                color= (0,255,0)
                self.lr=lr
            else: 
                # training accuracy did not improve check if this has happened for patience number of epochs
                # if so adjust learning rate
                if self.count>=self.patience -1:
                    color=(245, 170, 66)
                    self.lr= lr* self.factor # adjust the learning by factor
                    tf.keras.backend.set_value(self.model.optimizer.lr, self.lr) # set the learning rate in the optimizer
                    self.count=0 # reset the count to 0
                    self.stop_count=self.stop_count + 1
                    if self.dwell:
                        self.model.set_weights(LRA.best_weights) # return to better point in N space                        
                    else:
                        if v_loss<self.lowest_vloss:
                            self.lowest_vloss=v_loss                                    
                else:
                    self.count=self.count +1 # increment patience counter                    
        else: # training accuracy is above threshold so adjust learning rate based on validation loss
            monitor='val_loss'
            if v_loss< self.lowest_vloss: # check if the validation loss improved 
                self.lowest_vloss=v_loss # replace lowest validation loss with new validation loss                
                LRA.best_weights=self.model.get_weights() # validation loss improved so save the weights
                self.count=0 # reset count since validation loss improved  
                self.stop_count=0  
                color=(0,255,0)
                self.lr=lr
            else: # validation loss did not improve
                if self.count>=self.patience-1:
                    color=(245, 170, 66)
                    self.lr=self.lr * self.factor # adjust the learning rate
                    self.stop_count=self.stop_count + 1 # increment stop counter because lr was adjusted 
                    self.count=0 # reset counter
                    tf.keras.backend.set_value(self.model.optimizer.lr, self.lr) # set the learning rate in the optimizer
                    if self.dwell:
                        self.model.set_weights(LRA.best_weights) # return to better point in N space
                else: 
                    self.count =self.count +1 # increment the patience counter                    
                if acc>self.highest_tracc:
                    self.highest_tracc= acc
                    msg=f'{str(epoch+1):^3s}/{str(LRA.tepochs):4s} {loss:^9.3f}{acc*100:^9.3f}{v_loss:^9.5f}{v_acc*100:^9.3f}{current_lr:^9.5f}{self.lr:^9.5f}{monitor:^11s}{duration:^8.2f}'
                    print_in_color (msg,(0, 67, 54), (55,65,80))
        if self.stop_count> self.stop_patience - 1: # check if learning rate has been adjusted stop_count times with no improvement
            msg=f' training has been halted at epoch {epoch + 1} after {self.stop_patience} adjustments of learning rate with no improvement'
            print_in_color(msg, (0,255,0), (55,65,80))
            self.model.stop_training = True # stop training

# %%
epochs =110
patience= 15 # number of epochs to wait to adjust lr if monitored value does not improve
stop_patience =3 # number of epochs to wait before stopping training if monitored value does not improve
threshold=.95 # if train accuracy is < threshhold adjust monitor accuracy, else monitor validation loss
factor=.003 # factor to reduce lr by
dwell=True # experimental, if True and monitored metric does not improve on current epoch set  modelweights back to weights of previous epoch
freeze=True # if true free weights of  the base model
callbacks=[LRA(model=model,patience=patience,stop_patience=stop_patience, threshold=threshold,
                   factor=factor,dwell=dwell,model_name= model_name,  freeze=freeze, initial_epoch=0 )]
LRA.tepochs=epochs  # used to determine value of last epoch for printing
history=model.fit(x=train_gen, epochs=epochs, callbacks=callbacks, verbose=1,  validation_data=valid_gen, 
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
#  Starting training using  base model Mark1 with weights frozen to imagenet weights initializing LRA callback
#
# Epoch 1/110
# 2023-02-09 14:53:06.422525: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-02-09 14:53:09.965343: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 646/646 [==============================] - 120s 165ms/step - loss: 8.9538 - accuracy: 0.1063 - precision: 0.6533 - recall: 0.0047 - auc: 0.6653 - mae: 0.0500 - mse: 0.0250 - root_mean_squared_error: 0.1582 - val_loss: 7.4833 - val_accuracy: 0.0387 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5769 - val_mae: 0.0510 - val_mse: 0.0256 - val_root_mean_squared_error: 0.1601
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR   Monitor  Duration
#
# Epoch 2/110
# 646/646 [==============================] - 97s 150ms/step - loss: 5.4916 - accuracy: 0.2589 - precision: 0.8537 - recall: 0.0305 - auc: 0.8257 - mae: 0.0473 - mse: 0.0230 - root_mean_squared_error: 0.1515 - val_loss: 4.6357 - val_accuracy: 0.2693 - val_precision: 0.8636 - val_recall: 0.0147 - val_auc: 0.8260 - val_mae: 0.0483 - val_mse: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 3/110
# 646/646 [==============================] - 97s 150ms/step - loss: 3.5931 - accuracy: 0.3842 - precision: 0.9058 - recall: 0.0698 - auc: 0.9025 - mae: 0.0444 - mse: 0.0208 - root_mean_squared_error: 0.1444 - val_loss: 3.0960 - val_accuracy: 0.4450 - val_precision: 0.9340 - val_recall: 0.0766 - val_auc: 0.9249 - val_mae: 0.0438 - val_mse: 0.0203 - val_root_mean_squared_error: 0.1423
# Epoch 4/110
# 646/646 [==============================] - 96s 149ms/step - loss: 2.6110 - accuracy: 0.4954 - precision: 0.9292 - recall: 0.1269 - auc: 0.9414 - mae: 0.0410 - mse: 0.0186 - root_mean_squared_error: 0.1364 - val_loss: 2.4435 - val_accuracy: 0.5364 - val_precision: 0.9458 - val_recall: 0.1215 - val_auc: 0.9458 - val_mae: 0.0410 - val_mse: 0.0184 - val_root_mean_squared_error: 0.1357
# Epoch 5/110
# 646/646 [==============================] - 97s 150ms/step - loss: 2.0471 - accuracy: 0.5878 - precision: 0.9378 - recall: 0.2072 - auc: 0.9630 - mae: 0.0373 - mse: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 1.8445 - val_accuracy: 0.6254 - val_precision: 0.9424 - val_recall: 0.2786 - val_auc: 0.9672 - val_mae: 0.0349 - val_mse: 0.0149 - val_root_mean_squared_error: 0.1220
# Epoch 6/110
# 646/646 [==============================] - 96s 149ms/step - loss: 1.6975 - accuracy: 0.6529 - precision: 0.9393 - recall: 0.3042 - auc: 0.9741 - mae: 0.0336 - mse: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 1.7508 - val_accuracy: 0.6246 - val_precision: 0.9116 - val_recall: 0.3034 - val_auc: 0.9668 - val_mae: 0.0338 - val_mse: 0.0146 - val_root_mean_squared_error: 0.1210
# Epoch 7/110
# 646/646 [==============================] - 96s 149ms/step - loss: 1.4459 - accuracy: 0.7090 - precision: 0.9376 - recall: 0.3967 - auc: 0.9822 - mae: 0.0301 - mse: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 1.5143 - val_accuracy: 0.6718 - val_precision: 0.9250 - val_recall: 0.3916 - val_auc: 0.9772 - val_mae: 0.0301 - val_mse: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 8/110
# 646/646 [==============================] - 96s 149ms/step - loss: 1.2432 - accuracy: 0.7585 - precision: 0.9376 - recall: 0.4942 - auc: 0.9880 - mae: 0.0266 - mse: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 1.4098 - val_accuracy: 0.6858 - val_precision: 0.9206 - val_recall: 0.4574 - val_auc: 0.9782 - val_mae: 0.0283 - val_mse: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 9/110
# 646/646 [==============================] - 96s 149ms/step - loss: 1.0968 - accuracy: 0.7931 - precision: 0.9352 - recall: 0.5722 - auc: 0.9911 - mae: 0.0237 - mse: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 1.1410 - val_accuracy: 0.7554 - val_precision: 0.9253 - val_recall: 0.5944 - val_auc: 0.9862 - val_mae: 0.0224 - val_mse: 0.0093 - val_root_mean_squared_error: 0.0965
# Epoch 10/110
# 646/646 [==============================] - 97s 150ms/step - loss: 0.9927 - accuracy: 0.8110 - precision: 0.9348 - recall: 0.6312 - auc: 0.9933 - mae: 0.0214 - mse: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 1.0987 - val_accuracy: 0.7608 - val_precision: 0.9107 - val_recall: 0.6471 - val_auc: 0.9861 - val_mae: 0.0205 - val_mse: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 11/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.8910 - accuracy: 0.8365 - precision: 0.9361 - recall: 0.6861 - auc: 0.9948 - mae: 0.0190 - mse: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 1.0782 - val_accuracy: 0.7763 - val_precision: 0.8938 - val_recall: 0.6517 - val_auc: 0.9829 - val_mae: 0.0196 - val_mse: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 12/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.8038 - accuracy: 0.8588 - precision: 0.9402 - recall: 0.7372 - auc: 0.9963 - mae: 0.0169 - mse: 0.0062 - root_mean_squared_error: 0.0788 - val_loss: 0.9831 - val_accuracy: 0.7995 - val_precision: 0.9040 - val_recall: 0.7067 - val_auc: 0.9860 - val_mae: 0.0173 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 13/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.7211 - accuracy: 0.8761 - precision: 0.9472 - recall: 0.7793 - auc: 0.9971 - mae: 0.0149 - mse: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 1.0021 - val_accuracy: 0.7802 - val_precision: 0.9077 - val_recall: 0.6927 - val_auc: 0.9867 - val_mae: 0.0180 - val_mse: 0.0079 - val_root_mean_squared_error: 0.0890
# Epoch 14/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.6692 - accuracy: 0.8901 - precision: 0.9485 - recall: 0.8062 - auc: 0.9980 - mae: 0.0136 - mse: 0.0049 - root_mean_squared_error: 0.0698 - val_loss: 1.0115 - val_accuracy: 0.7833 - val_precision: 0.8830 - val_recall: 0.7183 - val_auc: 0.9849 - val_mae: 0.0169 - val_mse: 0.0079 - val_root_mean_squared_error: 0.0888
# Epoch 15/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.6308 - accuracy: 0.8973 - precision: 0.9495 - recall: 0.8297 - auc: 0.9981 - mae: 0.0124 - mse: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.9216 - val_accuracy: 0.8111 - val_precision: 0.8935 - val_recall: 0.7601 - val_auc: 0.9878 - val_mae: 0.0145 - val_mse: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 16/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.5867 - accuracy: 0.9131 - precision: 0.9536 - recall: 0.8527 - auc: 0.9986 - mae: 0.0112 - mse: 0.0039 - root_mean_squared_error: 0.0625 - val_loss: 0.9884 - val_accuracy: 0.7856 - val_precision: 0.8769 - val_recall: 0.7276 - val_auc: 0.9845 - val_mae: 0.0158 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 17/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.5565 - accuracy: 0.9202 - precision: 0.9578 - recall: 0.8670 - auc: 0.9987 - mae: 0.0102 - mse: 0.0036 - root_mean_squared_error: 0.0597 - val_loss: 0.9779 - val_accuracy: 0.7887 - val_precision: 0.8658 - val_recall: 0.7438 - val_auc: 0.9815 - val_mae: 0.0147 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 18/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.5241 - accuracy: 0.9256 - precision: 0.9580 - recall: 0.8828 - auc: 0.9990 - mae: 0.0093 - mse: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.9381 - val_accuracy: 0.8026 - val_precision: 0.8813 - val_recall: 0.7585 - val_auc: 0.9836 - val_mae: 0.0140 - val_mse: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 19/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.5251 - accuracy: 0.9257 - precision: 0.9546 - recall: 0.8849 - auc: 0.9988 - mae: 0.0090 - mse: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.9324 - val_accuracy: 0.7972 - val_precision: 0.8605 - val_recall: 0.7593 - val_auc: 0.9857 - val_mae: 0.0137 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 20/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.4992 - accuracy: 0.9315 - precision: 0.9576 - recall: 0.8987 - auc: 0.9990 - mae: 0.0083 - mse: 0.0030 - root_mean_squared_error: 0.0547 - val_loss: 1.0199 - val_accuracy: 0.7779 - val_precision: 0.8609 - val_recall: 0.7376 - val_auc: 0.9787 - val_mae: 0.0146 - val_mse: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 21/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.4774 - accuracy: 0.9374 - precision: 0.9612 - recall: 0.9050 - auc: 0.9991 - mae: 0.0077 - mse: 0.0027 - root_mean_squared_error: 0.0524 - val_loss: 1.0107 - val_accuracy: 0.7771 - val_precision: 0.8608 - val_recall: 0.7469 - val_auc: 0.9811 - val_mae: 0.0145 - val_mse: 0.0078 - val_root_mean_squared_error: 0.0884
# Epoch 22/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.4766 - accuracy: 0.9360 - precision: 0.9590 - recall: 0.9049 - auc: 0.9990 - mae: 0.0075 - mse: 0.0027 - root_mean_squared_error: 0.0524 - val_loss: 0.9833 - val_accuracy: 0.7995 - val_precision: 0.8517 - val_recall: 0.7601 - val_auc: 0.9806 - val_mae: 0.0133 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0879
# Epoch 23/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.4660 - accuracy: 0.9380 - precision: 0.9595 - recall: 0.9110 - auc: 0.9990 - mae: 0.0071 - mse: 0.0026 - root_mean_squared_error: 0.0511 - val_loss: 1.1058 - val_accuracy: 0.7639 - val_precision: 0.8304 - val_recall: 0.7237 - val_auc: 0.9760 - val_mae: 0.0155 - val_mse: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 24/110
# 646/646 [==============================] - 97s 149ms/step - loss: 0.4439 - accuracy: 0.9457 - precision: 0.9655 - recall: 0.9192 - auc: 0.9993 - mae: 0.0066 - mse: 0.0024 - root_mean_squared_error: 0.0486 - val_loss: 0.9644 - val_accuracy: 0.7879 - val_precision: 0.8495 - val_recall: 0.7515 - val_auc: 0.9820 - val_mae: 0.0135 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 25/110
# 646/646 [==============================] - 97s 149ms/step - loss: 0.4307 - accuracy: 0.9440 - precision: 0.9650 - recall: 0.9216 - auc: 0.9993 - mae: 0.0063 - mse: 0.0023 - root_mean_squared_error: 0.0476 - val_loss: 0.9553 - val_accuracy: 0.7918 - val_precision: 0.8547 - val_recall: 0.7647 - val_auc: 0.9827 - val_mae: 0.0132 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 26/110
# 646/646 [==============================] - 97s 150ms/step - loss: 0.4100 - accuracy: 0.9499 - precision: 0.9664 - recall: 0.9304 - auc: 0.9995 - mae: 0.0058 - mse: 0.0021 - root_mean_squared_error: 0.0454 - val_loss: 0.9940 - val_accuracy: 0.7949 - val_precision: 0.8448 - val_recall: 0.7709 - val_auc: 0.9799 - val_mae: 0.0128 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 27/110
# 646/646 [==============================] - 97s 150ms/step - loss: 0.4208 - accuracy: 0.9483 - precision: 0.9624 - recall: 0.9286 - auc: 0.9993 - mae: 0.0059 - mse: 0.0022 - root_mean_squared_error: 0.0471 - val_loss: 0.9562 - val_accuracy: 0.7988 - val_precision: 0.8446 - val_recall: 0.7616 - val_auc: 0.9827 - val_mae: 0.0127 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 28/110
# 646/646 [==============================] - 97s 150ms/step - loss: 0.4290 - accuracy: 0.9437 - precision: 0.9615 - recall: 0.9248 - auc: 0.9993 - mae: 0.0060 - mse: 0.0023 - root_mean_squared_error: 0.0478 - val_loss: 1.0026 - val_accuracy: 0.7841 - val_precision: 0.8412 - val_recall: 0.7546 - val_auc: 0.9799 - val_mae: 0.0137 - val_mse: 0.0080 - val_root_mean_squared_error: 0.0894
# Epoch 29/110
# 646/646 [==============================] - 97s 149ms/step - loss: 0.3949 - accuracy: 0.9576 - precision: 0.9713 - recall: 0.9425 - auc: 0.9995 - mae: 0.0052 - mse: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 1.0471 - val_accuracy: 0.7833 - val_precision: 0.8352 - val_recall: 0.7454 - val_auc: 0.9749 - val_mae: 0.0140 - val_mse: 0.0083 - val_root_mean_squared_error: 0.0912
# 29 /110    0.395   95.762   1.04713  78.328   0.00010  0.00010  val_loss   96.58
#
# Epoch 30/110
# 646/646 [==============================] - 97s 150ms/step - loss: 0.4120 - accuracy: 0.9522 - precision: 0.9683 - recall: 0.9353 - auc: 0.9992 - mae: 0.0054 - mse: 0.0020 - root_mean_squared_error: 0.0453 - val_loss: 0.9517 - val_accuracy: 0.8166 - val_precision: 0.8589 - val_recall: 0.7918 - val_auc: 0.9776 - val_mae: 0.0120 - val_mse: 0.0071 - val_root_mean_squared_error: 0.0845
# Epoch 31/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3938 - accuracy: 0.9552 - precision: 0.9677 - recall: 0.9402 - auc: 0.9994 - mae: 0.0050 - mse: 0.0019 - root_mean_squared_error: 0.0435 - val_loss: 0.9974 - val_accuracy: 0.8019 - val_precision: 0.8540 - val_recall: 0.7833 - val_auc: 0.9767 - val_mae: 0.0126 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 32/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3872 - accuracy: 0.9550 - precision: 0.9684 - recall: 0.9398 - auc: 0.9993 - mae: 0.0049 - mse: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.9789 - val_accuracy: 0.7972 - val_precision: 0.8472 - val_recall: 0.7724 - val_auc: 0.9785 - val_mae: 0.0124 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 33/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3848 - accuracy: 0.9575 - precision: 0.9690 - recall: 0.9420 - auc: 0.9996 - mae: 0.0048 - mse: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.8891 - val_accuracy: 0.8189 - val_precision: 0.8729 - val_recall: 0.8026 - val_auc: 0.9821 - val_mae: 0.0112 - val_mse: 0.0067 - val_root_mean_squared_error: 0.0818
# Epoch 34/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3852 - accuracy: 0.9562 - precision: 0.9664 - recall: 0.9421 - auc: 0.9992 - mae: 0.0047 - mse: 0.0018 - root_mean_squared_error: 0.0430 - val_loss: 1.0504 - val_accuracy: 0.7918 - val_precision: 0.8391 - val_recall: 0.7709 - val_auc: 0.9734 - val_mae: 0.0128 - val_mse: 0.0079 - val_root_mean_squared_error: 0.0890
# Epoch 35/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3675 - accuracy: 0.9597 - precision: 0.9697 - recall: 0.9447 - auc: 0.9996 - mae: 0.0045 - mse: 0.0017 - root_mean_squared_error: 0.0410 - val_loss: 0.9715 - val_accuracy: 0.8127 - val_precision: 0.8548 - val_recall: 0.7926 - val_auc: 0.9756 - val_mae: 0.0118 - val_mse: 0.0073 - val_root_mean_squared_error: 0.0852
# 35 /110    0.368   95.966   0.97153  81.269   0.00010  0.00010  val_loss   96.11
#
# Epoch 36/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3505 - accuracy: 0.9658 - precision: 0.9750 - recall: 0.9547 - auc: 0.9997 - mae: 0.0041 - mse: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 1.0116 - val_accuracy: 0.8019 - val_precision: 0.8462 - val_recall: 0.7833 - val_auc: 0.9744 - val_mae: 0.0120 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0873
# 36 /110    0.351   96.585   1.01159  80.186   0.00010  0.00010  val_loss   96.01
#
# Epoch 37/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3711 - accuracy: 0.9598 - precision: 0.9708 - recall: 0.9475 - auc: 0.9996 - mae: 0.0044 - mse: 0.0017 - root_mean_squared_error: 0.0411 - val_loss: 1.0343 - val_accuracy: 0.7964 - val_precision: 0.8295 - val_recall: 0.7717 - val_auc: 0.9763 - val_mae: 0.0126 - val_mse: 0.0080 - val_root_mean_squared_error: 0.0894
# Epoch 38/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3605 - accuracy: 0.9616 - precision: 0.9731 - recall: 0.9504 - auc: 0.9996 - mae: 0.0041 - mse: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 0.9629 - val_accuracy: 0.8065 - val_precision: 0.8525 - val_recall: 0.7786 - val_auc: 0.9796 - val_mae: 0.0123 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 39/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3586 - accuracy: 0.9610 - precision: 0.9723 - recall: 0.9491 - auc: 0.9995 - mae: 0.0041 - mse: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 0.9507 - val_accuracy: 0.8111 - val_precision: 0.8541 - val_recall: 0.7887 - val_auc: 0.9795 - val_mae: 0.0116 - val_mse: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 40/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3580 - accuracy: 0.9598 - precision: 0.9712 - recall: 0.9481 - auc: 0.9996 - mae: 0.0041 - mse: 0.0016 - root_mean_squared_error: 0.0400 - val_loss: 1.0499 - val_accuracy: 0.7933 - val_precision: 0.8445 - val_recall: 0.7732 - val_auc: 0.9723 - val_mae: 0.0127 - val_mse: 0.0078 - val_root_mean_squared_error: 0.0884
# Epoch 41/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3590 - accuracy: 0.9632 - precision: 0.9748 - recall: 0.9523 - auc: 0.9993 - mae: 0.0040 - mse: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 0.9223 - val_accuracy: 0.8158 - val_precision: 0.8623 - val_recall: 0.7949 - val_auc: 0.9800 - val_mae: 0.0115 - val_mse: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 42/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3496 - accuracy: 0.9630 - precision: 0.9725 - recall: 0.9531 - auc: 0.9996 - mae: 0.0039 - mse: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 0.9790 - val_accuracy: 0.8080 - val_precision: 0.8502 - val_recall: 0.7949 - val_auc: 0.9758 - val_mae: 0.0116 - val_mse: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 43/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3518 - accuracy: 0.9647 - precision: 0.9734 - recall: 0.9551 - auc: 0.9996 - mae: 0.0038 - mse: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 1.0066 - val_accuracy: 0.8050 - val_precision: 0.8460 - val_recall: 0.7864 - val_auc: 0.9755 - val_mae: 0.0121 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 44/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3522 - accuracy: 0.9624 - precision: 0.9723 - recall: 0.9550 - auc: 0.9995 - mae: 0.0037 - mse: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.9750 - val_accuracy: 0.8104 - val_precision: 0.8488 - val_recall: 0.7864 - val_auc: 0.9754 - val_mae: 0.0116 - val_mse: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 45/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3276 - accuracy: 0.9702 - precision: 0.9776 - recall: 0.9611 - auc: 0.9996 - mae: 0.0034 - mse: 0.0013 - root_mean_squared_error: 0.0358 - val_loss: 1.1211 - val_accuracy: 0.7763 - val_precision: 0.8247 - val_recall: 0.7647 - val_auc: 0.9683 - val_mae: 0.0130 - val_mse: 0.0086 - val_root_mean_squared_error: 0.0927
# 45 /110    0.328   97.020   1.12107  77.632   0.00010  0.00010  val_loss   96.06
#
# Epoch 46/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3155 - accuracy: 0.9690 - precision: 0.9773 - recall: 0.9621 - auc: 0.9997 - mae: 0.0032 - mse: 0.0012 - root_mean_squared_error: 0.0348 - val_loss: 1.0711 - val_accuracy: 0.7895 - val_precision: 0.8406 - val_recall: 0.7755 - val_auc: 0.9715 - val_mae: 0.0125 - val_mse: 0.0081 - val_root_mean_squared_error: 0.0897
# Epoch 47/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3511 - accuracy: 0.9626 - precision: 0.9706 - recall: 0.9523 - auc: 0.9991 - mae: 0.0038 - mse: 0.0016 - root_mean_squared_error: 0.0394 - val_loss: 1.0699 - val_accuracy: 0.7895 - val_precision: 0.8331 - val_recall: 0.7724 - val_auc: 0.9717 - val_mae: 0.0127 - val_mse: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 48/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3417 - accuracy: 0.9663 - precision: 0.9744 - recall: 0.9570 - auc: 0.9994 - mae: 0.0035 - mse: 0.0014 - root_mean_squared_error: 0.0376 - val_loss: 1.1323 - val_accuracy: 0.7895 - val_precision: 0.8325 - val_recall: 0.7732 - val_auc: 0.9675 - val_mae: 0.0127 - val_mse: 0.0084 - val_root_mean_squared_error: 0.0915
# Epoch 49/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3489 - accuracy: 0.9691 - precision: 0.9772 - recall: 0.9568 - auc: 0.9996 - mae: 0.0039 - mse: 0.0014 - root_mean_squared_error: 0.0370 - val_loss: 0.8877 - val_accuracy: 0.8313 - val_precision: 0.8679 - val_recall: 0.8088 - val_auc: 0.9813 - val_mae: 0.0107 - val_mse: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 50/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3492 - accuracy: 0.9672 - precision: 0.9766 - recall: 0.9552 - auc: 0.9997 - mae: 0.0040 - mse: 0.0014 - root_mean_squared_error: 0.0374 - val_loss: 0.8875 - val_accuracy: 0.8282 - val_precision: 0.8683 - val_recall: 0.8111 - val_auc: 0.9805 - val_mae: 0.0107 - val_mse: 0.0066 - val_root_mean_squared_error: 0.0814
# Epoch 51/110
# 646/646 [==============================] - 97s 150ms/step - loss: 0.3451 - accuracy: 0.9704 - precision: 0.9798 - recall: 0.9593 - auc: 0.9996 - mae: 0.0038 - mse: 0.0013 - root_mean_squared_error: 0.0362 - val_loss: 0.8808 - val_accuracy: 0.8320 - val_precision: 0.8694 - val_recall: 0.8142 - val_auc: 0.9806 - val_mae: 0.0107 - val_mse: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 52/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3456 - accuracy: 0.9668 - precision: 0.9777 - recall: 0.9575 - auc: 0.9997 - mae: 0.0039 - mse: 0.0014 - root_mean_squared_error: 0.0369 - val_loss: 0.8799 - val_accuracy: 0.8320 - val_precision: 0.8711 - val_recall: 0.8158 - val_auc: 0.9803 - val_mae: 0.0106 - val_mse: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 53/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3360 - accuracy: 0.9730 - precision: 0.9818 - recall: 0.9618 - auc: 0.9997 - mae: 0.0037 - mse: 0.0012 - root_mean_squared_error: 0.0348 - val_loss: 0.8766 - val_accuracy: 0.8305 - val_precision: 0.8680 - val_recall: 0.8142 - val_auc: 0.9803 - val_mae: 0.0106 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 54/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3359 - accuracy: 0.9700 - precision: 0.9791 - recall: 0.9610 - auc: 0.9998 - mae: 0.0037 - mse: 0.0012 - root_mean_squared_error: 0.0353 - val_loss: 0.8720 - val_accuracy: 0.8297 - val_precision: 0.8699 - val_recall: 0.8173 - val_auc: 0.9807 - val_mae: 0.0105 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 55/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3297 - accuracy: 0.9741 - precision: 0.9814 - recall: 0.9641 - auc: 0.9999 - mae: 0.0036 - mse: 0.0012 - root_mean_squared_error: 0.0343 - val_loss: 0.8752 - val_accuracy: 0.8305 - val_precision: 0.8651 - val_recall: 0.8142 - val_auc: 0.9807 - val_mae: 0.0106 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0809
# 55 /110    0.330   97.407   0.87523  83.050   0.00000  0.00000  val_loss   95.86
#
# Epoch 56/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3345 - accuracy: 0.9707 - precision: 0.9788 - recall: 0.9612 - auc: 0.9998 - mae: 0.0037 - mse: 0.0013 - root_mean_squared_error: 0.0355 - val_loss: 0.8686 - val_accuracy: 0.8313 - val_precision: 0.8654 - val_recall: 0.8158 - val_auc: 0.9811 - val_mae: 0.0105 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 57/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3258 - accuracy: 0.9749 - precision: 0.9839 - recall: 0.9668 - auc: 0.9998 - mae: 0.0035 - mse: 0.0011 - root_mean_squared_error: 0.0332 - val_loss: 0.8682 - val_accuracy: 0.8328 - val_precision: 0.8712 - val_recall: 0.8166 - val_auc: 0.9815 - val_mae: 0.0105 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 58/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3316 - accuracy: 0.9703 - precision: 0.9795 - recall: 0.9613 - auc: 0.9999 - mae: 0.0036 - mse: 0.0012 - root_mean_squared_error: 0.0353 - val_loss: 0.8678 - val_accuracy: 0.8328 - val_precision: 0.8683 - val_recall: 0.8166 - val_auc: 0.9808 - val_mae: 0.0104 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 59/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3231 - accuracy: 0.9745 - precision: 0.9828 - recall: 0.9662 - auc: 0.9998 - mae: 0.0034 - mse: 0.0011 - root_mean_squared_error: 0.0334 - val_loss: 0.8640 - val_accuracy: 0.8305 - val_precision: 0.8682 - val_recall: 0.8158 - val_auc: 0.9811 - val_mae: 0.0104 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 60/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3212 - accuracy: 0.9747 - precision: 0.9822 - recall: 0.9661 - auc: 0.9999 - mae: 0.0034 - mse: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 0.8632 - val_accuracy: 0.8305 - val_precision: 0.8702 - val_recall: 0.8150 - val_auc: 0.9811 - val_mae: 0.0104 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 61/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3207 - accuracy: 0.9730 - precision: 0.9812 - recall: 0.9652 - auc: 0.9998 - mae: 0.0034 - mse: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 0.8619 - val_accuracy: 0.8313 - val_precision: 0.8680 - val_recall: 0.8142 - val_auc: 0.9811 - val_mae: 0.0104 - val_mse: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 62/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3192 - accuracy: 0.9762 - precision: 0.9836 - recall: 0.9672 - auc: 0.9999 - mae: 0.0034 - mse: 0.0011 - root_mean_squared_error: 0.0331 - val_loss: 0.8572 - val_accuracy: 0.8320 - val_precision: 0.8712 - val_recall: 0.8166 - val_auc: 0.9812 - val_mae: 0.0104 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0802
# Epoch 63/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3172 - accuracy: 0.9744 - precision: 0.9808 - recall: 0.9673 - auc: 0.9998 - mae: 0.0033 - mse: 0.0011 - root_mean_squared_error: 0.0332 - val_loss: 0.8550 - val_accuracy: 0.8320 - val_precision: 0.8728 - val_recall: 0.8181 - val_auc: 0.9815 - val_mae: 0.0103 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 64/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3062 - accuracy: 0.9776 - precision: 0.9845 - recall: 0.9723 - auc: 0.9999 - mae: 0.0030 - mse: 9.4570e-04 - root_mean_squared_error: 0.0308 - val_loss: 0.8532 - val_accuracy: 0.8328 - val_precision: 0.8695 - val_recall: 0.8150 - val_auc: 0.9815 - val_mae: 0.0103 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 65/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3098 - accuracy: 0.9781 - precision: 0.9848 - recall: 0.9697 - auc: 0.9999 - mae: 0.0032 - mse: 9.9973e-04 - root_mean_squared_error: 0.0316 - val_loss: 0.8497 - val_accuracy: 0.8336 - val_precision: 0.8724 - val_recall: 0.8150 - val_auc: 0.9816 - val_mae: 0.0103 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0799
# Epoch 66/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3096 - accuracy: 0.9765 - precision: 0.9836 - recall: 0.9685 - auc: 0.9998 - mae: 0.0032 - mse: 0.0010 - root_mean_squared_error: 0.0317 - val_loss: 0.8485 - val_accuracy: 0.8320 - val_precision: 0.8711 - val_recall: 0.8158 - val_auc: 0.9816 - val_mae: 0.0103 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0799
# Epoch 67/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3076 - accuracy: 0.9777 - precision: 0.9845 - recall: 0.9705 - auc: 0.9999 - mae: 0.0032 - mse: 0.0010 - root_mean_squared_error: 0.0317 - val_loss: 0.8490 - val_accuracy: 0.8328 - val_precision: 0.8687 - val_recall: 0.8142 - val_auc: 0.9816 - val_mae: 0.0103 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0800
# 67 /110    0.308   97.775   0.84903  83.282   0.00000  0.00000  val_loss   95.93
#
# Epoch 68/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3047 - accuracy: 0.9786 - precision: 0.9843 - recall: 0.9704 - auc: 0.9999 - mae: 0.0031 - mse: 9.7738e-04 - root_mean_squared_error: 0.0313 - val_loss: 0.8465 - val_accuracy: 0.8336 - val_precision: 0.8671 - val_recall: 0.8181 - val_auc: 0.9820 - val_mae: 0.0102 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 69/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3062 - accuracy: 0.9792 - precision: 0.9850 - recall: 0.9715 - auc: 0.9998 - mae: 0.0031 - mse: 9.8675e-04 - root_mean_squared_error: 0.0314 - val_loss: 0.8449 - val_accuracy: 0.8344 - val_precision: 0.8713 - val_recall: 0.8173 - val_auc: 0.9820 - val_mae: 0.0103 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 70/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.3107 - accuracy: 0.9757 - precision: 0.9828 - recall: 0.9676 - auc: 0.9999 - mae: 0.0033 - mse: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 0.8440 - val_accuracy: 0.8359 - val_precision: 0.8719 - val_recall: 0.8166 - val_auc: 0.9820 - val_mae: 0.0102 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0797
# Epoch 71/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3045 - accuracy: 0.9774 - precision: 0.9843 - recall: 0.9678 - auc: 0.9999 - mae: 0.0032 - mse: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 0.8411 - val_accuracy: 0.8336 - val_precision: 0.8705 - val_recall: 0.8166 - val_auc: 0.9824 - val_mae: 0.0102 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0797
# Epoch 72/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2978 - accuracy: 0.9803 - precision: 0.9860 - recall: 0.9725 - auc: 0.9998 - mae: 0.0030 - mse: 9.0995e-04 - root_mean_squared_error: 0.0302 - val_loss: 0.8388 - val_accuracy: 0.8313 - val_precision: 0.8725 - val_recall: 0.8158 - val_auc: 0.9813 - val_mae: 0.0102 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 73/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3005 - accuracy: 0.9786 - precision: 0.9835 - recall: 0.9714 - auc: 0.9999 - mae: 0.0031 - mse: 9.7250e-04 - root_mean_squared_error: 0.0312 - val_loss: 0.8405 - val_accuracy: 0.8359 - val_precision: 0.8713 - val_recall: 0.8173 - val_auc: 0.9813 - val_mae: 0.0102 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0796
# 73 /110    0.301   97.862   0.84049  83.591   0.00000  0.00000  val_loss   95.84
#
# Epoch 74/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2977 - accuracy: 0.9788 - precision: 0.9858 - recall: 0.9712 - auc: 0.9999 - mae: 0.0030 - mse: 9.3234e-04 - root_mean_squared_error: 0.0305 - val_loss: 0.8397 - val_accuracy: 0.8344 - val_precision: 0.8718 - val_recall: 0.8158 - val_auc: 0.9820 - val_mae: 0.0102 - val_mse: 0.0064 - val_root_mean_squared_error: 0.0798
# 74 /110    0.298   97.881   0.83967  83.437   0.00000  0.00000  val_loss   95.92
#
# Epoch 75/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.3003 - accuracy: 0.9782 - precision: 0.9837 - recall: 0.9710 - auc: 0.9998 - mae: 0.0030 - mse: 9.7282e-04 - root_mean_squared_error: 0.0312 - val_loss: 0.8372 - val_accuracy: 0.8375 - val_precision: 0.8697 - val_recall: 0.8212 - val_auc: 0.9820 - val_mae: 0.0102 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0796
# Epoch 76/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2913 - accuracy: 0.9820 - precision: 0.9870 - recall: 0.9743 - auc: 0.9999 - mae: 0.0029 - mse: 8.7122e-04 - root_mean_squared_error: 0.0295 - val_loss: 0.8332 - val_accuracy: 0.8367 - val_precision: 0.8716 - val_recall: 0.8197 - val_auc: 0.9817 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 77/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2960 - accuracy: 0.9795 - precision: 0.9853 - recall: 0.9716 - auc: 0.9999 - mae: 0.0030 - mse: 9.3498e-04 - root_mean_squared_error: 0.0306 - val_loss: 0.8312 - val_accuracy: 0.8382 - val_precision: 0.8762 - val_recall: 0.8166 - val_auc: 0.9824 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 78/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2950 - accuracy: 0.9792 - precision: 0.9857 - recall: 0.9711 - auc: 0.9999 - mae: 0.0030 - mse: 9.4345e-04 - root_mean_squared_error: 0.0307 - val_loss: 0.8304 - val_accuracy: 0.8351 - val_precision: 0.8705 - val_recall: 0.8166 - val_auc: 0.9824 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 79/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2901 - accuracy: 0.9794 - precision: 0.9867 - recall: 0.9717 - auc: 0.9999 - mae: 0.0029 - mse: 8.8489e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.8334 - val_accuracy: 0.8351 - val_precision: 0.8676 - val_recall: 0.8166 - val_auc: 0.9816 - val_mae: 0.0102 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0795
# 79 /110    0.290   97.939   0.83340  83.514   0.00000  0.00000  val_loss   95.76
#
# Epoch 80/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2909 - accuracy: 0.9803 - precision: 0.9857 - recall: 0.9745 - auc: 0.9999 - mae: 0.0029 - mse: 8.9918e-04 - root_mean_squared_error: 0.0300 - val_loss: 0.8317 - val_accuracy: 0.8344 - val_precision: 0.8718 - val_recall: 0.8158 - val_auc: 0.9817 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0794
# 80 /110    0.291   98.026   0.83175  83.437   0.00000  0.00000  val_loss   95.90
#
# Epoch 81/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2888 - accuracy: 0.9807 - precision: 0.9869 - recall: 0.9739 - auc: 0.9999 - mae: 0.0029 - mse: 8.7946e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.8271 - val_accuracy: 0.8390 - val_precision: 0.8711 - val_recall: 0.8212 - val_auc: 0.9821 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 82/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2942 - accuracy: 0.9782 - precision: 0.9844 - recall: 0.9713 - auc: 0.9998 - mae: 0.0030 - mse: 9.5801e-04 - root_mean_squared_error: 0.0310 - val_loss: 0.8318 - val_accuracy: 0.8351 - val_precision: 0.8699 - val_recall: 0.8173 - val_auc: 0.9813 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 83/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2897 - accuracy: 0.9782 - precision: 0.9850 - recall: 0.9713 - auc: 0.9998 - mae: 0.0029 - mse: 9.1066e-04 - root_mean_squared_error: 0.0302 - val_loss: 0.8266 - val_accuracy: 0.8382 - val_precision: 0.8720 - val_recall: 0.8173 - val_auc: 0.9817 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 84/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2848 - accuracy: 0.9832 - precision: 0.9878 - recall: 0.9747 - auc: 0.9999 - mae: 0.0029 - mse: 8.4601e-04 - root_mean_squared_error: 0.0291 - val_loss: 0.8298 - val_accuracy: 0.8359 - val_precision: 0.8700 - val_recall: 0.8181 - val_auc: 0.9813 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0794
# 84 /110    0.285   98.317   0.82978  83.591   0.00000  0.00000  val_loss   95.81
#
# Epoch 85/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2832 - accuracy: 0.9807 - precision: 0.9862 - recall: 0.9743 - auc: 0.9999 - mae: 0.0028 - mse: 8.4274e-04 - root_mean_squared_error: 0.0290 - val_loss: 0.8263 - val_accuracy: 0.8359 - val_precision: 0.8724 - val_recall: 0.8204 - val_auc: 0.9813 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 86/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2782 - accuracy: 0.9837 - precision: 0.9880 - recall: 0.9757 - auc: 1.0000 - mae: 0.0027 - mse: 7.7791e-04 - root_mean_squared_error: 0.0279 - val_loss: 0.8254 - val_accuracy: 0.8375 - val_precision: 0.8689 - val_recall: 0.8204 - val_auc: 0.9821 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 87/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2822 - accuracy: 0.9818 - precision: 0.9869 - recall: 0.9751 - auc: 0.9998 - mae: 0.0027 - mse: 8.3481e-04 - root_mean_squared_error: 0.0289 - val_loss: 0.8256 - val_accuracy: 0.8351 - val_precision: 0.8694 - val_recall: 0.8189 - val_auc: 0.9817 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 88/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2808 - accuracy: 0.9814 - precision: 0.9867 - recall: 0.9747 - auc: 1.0000 - mae: 0.0028 - mse: 8.3427e-04 - root_mean_squared_error: 0.0289 - val_loss: 0.8207 - val_accuracy: 0.8382 - val_precision: 0.8709 - val_recall: 0.8197 - val_auc: 0.9821 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 89/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2785 - accuracy: 0.9821 - precision: 0.9872 - recall: 0.9748 - auc: 0.9999 - mae: 0.0027 - mse: 8.0946e-04 - root_mean_squared_error: 0.0285 - val_loss: 0.8195 - val_accuracy: 0.8390 - val_precision: 0.8730 - val_recall: 0.8243 - val_auc: 0.9817 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 90/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2836 - accuracy: 0.9804 - precision: 0.9870 - recall: 0.9735 - auc: 0.9999 - mae: 0.0029 - mse: 8.8784e-04 - root_mean_squared_error: 0.0298 - val_loss: 0.8221 - val_accuracy: 0.8382 - val_precision: 0.8659 - val_recall: 0.8197 - val_auc: 0.9817 - val_mae: 0.0101 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 91/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2779 - accuracy: 0.9831 - precision: 0.9900 - recall: 0.9764 - auc: 0.9999 - mae: 0.0027 - mse: 7.7366e-04 - root_mean_squared_error: 0.0278 - val_loss: 0.8178 - val_accuracy: 0.8375 - val_precision: 0.8713 - val_recall: 0.8228 - val_auc: 0.9821 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 92/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2747 - accuracy: 0.9823 - precision: 0.9877 - recall: 0.9762 - auc: 0.9999 - mae: 0.0027 - mse: 7.8809e-04 - root_mean_squared_error: 0.0281 - val_loss: 0.8192 - val_accuracy: 0.8367 - val_precision: 0.8718 - val_recall: 0.8212 - val_auc: 0.9825 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 93/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2781 - accuracy: 0.9825 - precision: 0.9875 - recall: 0.9746 - auc: 0.9999 - mae: 0.0028 - mse: 8.3886e-04 - root_mean_squared_error: 0.0290 - val_loss: 0.8124 - val_accuracy: 0.8390 - val_precision: 0.8766 - val_recall: 0.8251 - val_auc: 0.9818 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 94/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2780 - accuracy: 0.9824 - precision: 0.9871 - recall: 0.9752 - auc: 0.9998 - mae: 0.0028 - mse: 8.4919e-04 - root_mean_squared_error: 0.0291 - val_loss: 0.8113 - val_accuracy: 0.8390 - val_precision: 0.8730 - val_recall: 0.8243 - val_auc: 0.9821 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 95/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2751 - accuracy: 0.9822 - precision: 0.9874 - recall: 0.9758 - auc: 0.9999 - mae: 0.0027 - mse: 7.9961e-04 - root_mean_squared_error: 0.0283 - val_loss: 0.8157 - val_accuracy: 0.8382 - val_precision: 0.8712 - val_recall: 0.8220 - val_auc: 0.9821 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 96/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2786 - accuracy: 0.9807 - precision: 0.9868 - recall: 0.9749 - auc: 0.9999 - mae: 0.0028 - mse: 8.5804e-04 - root_mean_squared_error: 0.0293 - val_loss: 0.8191 - val_accuracy: 0.8375 - val_precision: 0.8702 - val_recall: 0.8197 - val_auc: 0.9814 - val_mae: 0.0100 - val_mse: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 97/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2724 - accuracy: 0.9818 - precision: 0.9866 - recall: 0.9777 - auc: 0.9999 - mae: 0.0026 - mse: 7.8827e-04 - root_mean_squared_error: 0.0281 - val_loss: 0.8109 - val_accuracy: 0.8398 - val_precision: 0.8766 - val_recall: 0.8251 - val_auc: 0.9814 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 98/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2699 - accuracy: 0.9842 - precision: 0.9888 - recall: 0.9780 - auc: 0.9999 - mae: 0.0026 - mse: 7.6589e-04 - root_mean_squared_error: 0.0277 - val_loss: 0.8148 - val_accuracy: 0.8344 - val_precision: 0.8695 - val_recall: 0.8197 - val_auc: 0.9814 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0789
# 98 /110    0.270   98.423   0.81478  83.437   0.00000  0.00000  val_loss   95.70
#
# Epoch 99/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2702 - accuracy: 0.9836 - precision: 0.9886 - recall: 0.9776 - auc: 0.9999 - mae: 0.0027 - mse: 7.7747e-04 - root_mean_squared_error: 0.0279 - val_loss: 0.8118 - val_accuracy: 0.8398 - val_precision: 0.8720 - val_recall: 0.8228 - val_auc: 0.9818 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 100/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2720 - accuracy: 0.9796 - precision: 0.9859 - recall: 0.9741 - auc: 0.9999 - mae: 0.0027 - mse: 8.3555e-04 - root_mean_squared_error: 0.0289 - val_loss: 0.8080 - val_accuracy: 0.8406 - val_precision: 0.8744 - val_recall: 0.8243 - val_auc: 0.9818 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 101/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2743 - accuracy: 0.9819 - precision: 0.9865 - recall: 0.9763 - auc: 0.9999 - mae: 0.0027 - mse: 8.4797e-04 - root_mean_squared_error: 0.0291 - val_loss: 0.8087 - val_accuracy: 0.8421 - val_precision: 0.8744 - val_recall: 0.8243 - val_auc: 0.9814 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0786
# Epoch 102/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2683 - accuracy: 0.9826 - precision: 0.9868 - recall: 0.9777 - auc: 0.9999 - mae: 0.0026 - mse: 7.8447e-04 - root_mean_squared_error: 0.0280 - val_loss: 0.8127 - val_accuracy: 0.8375 - val_precision: 0.8718 - val_recall: 0.8212 - val_auc: 0.9814 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 103/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2684 - accuracy: 0.9834 - precision: 0.9881 - recall: 0.9759 - auc: 1.0000 - mae: 0.0027 - mse: 7.9913e-04 - root_mean_squared_error: 0.0283 - val_loss: 0.8102 - val_accuracy: 0.8413 - val_precision: 0.8735 - val_recall: 0.8228 - val_auc: 0.9818 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0788
# Epoch 104/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2704 - accuracy: 0.9824 - precision: 0.9875 - recall: 0.9753 - auc: 0.9998 - mae: 0.0027 - mse: 8.1218e-04 - root_mean_squared_error: 0.0285 - val_loss: 0.8088 - val_accuracy: 0.8398 - val_precision: 0.8750 - val_recall: 0.8235 - val_auc: 0.9814 - val_mae: 0.0099 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 105/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2644 - accuracy: 0.9846 - precision: 0.9889 - recall: 0.9775 - auc: 0.9999 - mae: 0.0026 - mse: 7.4572e-04 - root_mean_squared_error: 0.0273 - val_loss: 0.8084 - val_accuracy: 0.8390 - val_precision: 0.8721 - val_recall: 0.8235 - val_auc: 0.9818 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0788
# 105/110    0.264   98.462   0.80840  83.901   0.00000  0.00000  val_loss   96.01
#
# Epoch 106/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2662 - accuracy: 0.9828 - precision: 0.9880 - recall: 0.9763 - auc: 0.9999 - mae: 0.0026 - mse: 7.7066e-04 - root_mean_squared_error: 0.0278 - val_loss: 0.8042 - val_accuracy: 0.8406 - val_precision: 0.8765 - val_recall: 0.8243 - val_auc: 0.9814 - val_mae: 0.0099 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0786
# Epoch 107/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2616 - accuracy: 0.9845 - precision: 0.9881 - recall: 0.9793 - auc: 1.0000 - mae: 0.0025 - mse: 7.2254e-04 - root_mean_squared_error: 0.0269 - val_loss: 0.8081 - val_accuracy: 0.8375 - val_precision: 0.8712 - val_recall: 0.8220 - val_auc: 0.9810 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0788
# Epoch 108/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2659 - accuracy: 0.9828 - precision: 0.9887 - recall: 0.9761 - auc: 1.0000 - mae: 0.0026 - mse: 7.8407e-04 - root_mean_squared_error: 0.0280 - val_loss: 0.8040 - val_accuracy: 0.8382 - val_precision: 0.8724 - val_recall: 0.8204 - val_auc: 0.9818 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 109/110
# 646/646 [==============================] - 96s 149ms/step - loss: 0.2650 - accuracy: 0.9827 - precision: 0.9875 - recall: 0.9764 - auc: 1.0000 - mae: 0.0027 - mse: 7.9826e-04 - root_mean_squared_error: 0.0283 - val_loss: 0.8034 - val_accuracy: 0.8390 - val_precision: 0.8744 - val_recall: 0.8243 - val_auc: 0.9814 - val_mae: 0.0099 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0786
# Epoch 110/110
# 646/646 [==============================] - 96s 148ms/step - loss: 0.2594 - accuracy: 0.9837 - precision: 0.9898 - recall: 0.9777 - auc: 1.0000 - mae: 0.0025 - mse: 7.1491e-04 - root_mean_squared_error: 0.0267 - val_loss: 0.8049 - val_accuracy: 0.8382 - val_precision: 0.8720 - val_recall: 0.8228 - val_auc: 0.9818 - val_mae: 0.0100 - val_mse: 0.0062 - val_root_mean_squared_error: 0.0787

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 38:
        # create a confusion matrix 
        cm = confusion_matrix(y_true, y_pred )        
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %%
tr_plot(history,0)
save_dir=r'./'
subject='fruits'
acc=model.evaluate( test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1]*100
msg=f'accuracy on the test set is {acc:5.2f} %'
print_in_color(msg, (0,255,0),(55,65,80))
save_id=str (model_name +  '-' + subject +'-'+ str(acc)[:str(acc).rfind('.')+3] + '.h5')
save_loc=os.path.join(save_dir, save_id)
model.save(save_loc)
# Out:
# 17/17 [==============================] - 19s 774ms/step - loss: 0.7662 - accuracy: 0.8491 - precision: 0.8920 - recall: 0.8313 - auc: 0.9824 - mae: 0.0094 - mse: 0.0057 - root_mean_squared_error: 0.0754
# accuracy on the test set is 84.91 %

# %%
print_code=0
preds=model.predict(test_gen) 
print_info( test_gen, preds, print_code, save_dir, subject )
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#  t_resized_0       0.95      0.84      0.89        45
#  t_resized_1       0.94      0.86      0.90        36
# t_resized_10       0.80      0.89      0.84        27
# t_resized_11       0.92      0.90      0.91        39
# t_resized_12       0.84      0.82      0.83        39
# t_resized_13       0.93      0.87      0.90        30
# t_resized_14       0.83      0.75      0.79        40
# t_resized_15       0.59      0.82      0.69        28
# t_resized_16       0.85      0.94      0.89        35
# t_resized_17       0.95      0.88      0.92        43
# t_resized_18       0.79      0.85      0.81        26
# t_resized_19       0.86      0.77      0.81        39
#  t_resized_2       0.93      0.76      0.83        33
# t_resized_20       0.90      0.90      0.90        40
# t_resized_21       0.92      0.82      0.87        28
# t_resized_22       0.69      0.71      0.70        35
# t_resized_23       0.74      0.89      0.81        36
# t_resized_24       0.87      0.87      0.87        31
# t_resized_25       0.86      0.94      0.90        33
# t_resized_26       1.00      0.75      0.86        36
# t_resized_27       0.94      0.83      0.88        35
# t_resized_28       0.90      0.92      0.91        38
# t_resized_29       0.90      0.79      0.84        33
#  t_resized_3       0.73      0.62      0.67        39
# t_resized_30       0.92      0.89      0.90        37
# t_resized_31       0.76      0.95      0.84        20
# t_resized_32       0.80      0.97      0.88        29
# t_resized_33       0.82      0.87      0.85        38
# t_resized_34       0.81      0.85      0.83        34
# t_resized_35       0.93      0.89      0.91        28
# t_resized_36       0.90      0.97      0.93        29
# t_resized_37       0.97      0.87      0.92        38
#  t_resized_4       0.78      0.81      0.79        31
#  t_resized_5       0.85      0.90      0.88        31
#  t_resized_6       0.81      0.83      0.82        35
#  t_resized_7       0.65      0.88      0.75        25
#  t_resized_8       0.83      0.83      0.83        36
#  t_resized_9       0.92      0.89      0.90        37
#
#     accuracy                           0.85      1292
#    macro avg       0.85      0.85      0.85      1292
# weighted avg       0.86      0.85      0.85      1292
